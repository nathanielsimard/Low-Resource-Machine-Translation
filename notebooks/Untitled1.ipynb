# %%
import math

# %%
max(1,4)
# Out:
# 4

# %%
' '.join(['a', 'b'])
# Out:
# 'a b'

# %%
def read_file(file_name: str):
    """Read file and returns paragraphs."""
    output = []
    with open(file_name, "r") as stream:
        for line in stream:
            tokens = line.strip()
            output.append(tokens.split())
    return output

# %%
t = read_file("../data/splitted_data/train_token.fr")

# %%
all_french_words = set()
for fr in t:
    for word in fr:
        if word not in all_french_words:
            all_french_words.add(word)

# %%
all_french_words
# Out:
# {'éclairci',
#  'claire',
#  'vraie',
#  'amnistié',
#  'globales',
#  'désaveu',
#  'ségrégation',
#  'soin',
#  'sortira',
#  'manipulée',
#  'adressons',
#  'formidable',
#  'piraterie',
#  'satisfaite',
#  'chenille',
#  'Jeux',
#  'passive',
#  'Mann',
#  'García',
#  'détermination',
#  'financés',
#  'concernent',
#  'adoptant',
#  'lente',
#  'implique',
#  'renvoi',
#  'Susan',
#  'News',
#  'autoritaires',
#  'déduction',
#  '355',
#  'précaution',
#  'baigner',
#  'anglais',
#  'hétérogénéité',
#  'Étant',
#  'homosexuels',
#  'insulte',
#  'ouvrant',
#  'technologie',
#  'complètent',
#  'élaboré',
#  'lèvent',
#  'appelées',
#  'préconisé',
#  'partiale',
#  'sauvages',
#  'maigres',
#  'récalcitrants',
#  'excellents',
#  'gazole',
#  'lacune',
#  'utiles',
#  'position',
#  'regret',
#  'non-discrimination',
#  'clandestins',
#  'exprimée',
#  'Environ',
#  'verts',
#  'insiste',
#  'coopérer',
#  'Projetons',
#  'complètes',
#  'immenses',
#  'Chef',
#  'paradoxe',
#  'des',
#  'procédure',
#  'Schengen',
#  'mélanges',
#  'aidée',
#  'Président',
#  'plusieurs',
#  'commerciaux',
#  'absolue',
#  'blessé',
#  'éventuelle',
#  'solide',
#  'sortant',
#  'YouTube',
#  'artistiques',
#  'pèseraient',
#  'Wiebenga',
#  'océanique',
#  'Seule',
#  'priorité',
#  'récoltes',
#  'rassuré',
#  'démarrera',
#  'épanouie',
#  'Juncker',
#  'manifestèrent',
#  'restreint',
#  'Démarrage',
#  'quotidien',
#  'consenti',
#  'chiffre',
#  'rénover',
#  'sommes',
#  'proposerais',
#  'réexaminer',
#  'Uyttebroeck',
#  'demandera',
#  'aborde',
#  'informaticien',
#  'multinationales',
#  'remplit',
#  'jupes',
#  'recyclage',
#  'Polonais',
#  'plaise',
#  'flexibles',
#  'Allemands',
#  'déjeunons',
#  'pensez',
#  'mutuel',
#  'chronique',
#  'dessus',
#  'réorganisent',
#  'entraîné',
#  'ranger',
#  'résiste',
#  'Chastel',
#  'visant',
#  'exploser',
#  'auditeur',
#  'Méditerranée',
#  'requins',
#  'Effectivement',
#  'gère',
#  'le',
#  'mère',
#  'traditionnels',
#  'injuste',
#  'Donc',
#  'soulevée',
#  'adorerais',
#  'Lituanie',
#  'Existe',
#  'complémentarité',
#  'prestation',
#  'Zana',
#  'désagréable',
#  '1965',
#  'Leur',
#  'nôtre',
#  'soutiendrai',
#  'exercée',
#  'période',
#  'surévaluer',
#  'celle',
#  'interventions',
#  'critiquer',
#  'lugubre',
#  'munitions',
#  'identifieront',
#  'monumental',
#  'soient',
#  'parti',
#  'contre',
#  'perspective',
#  'Ah',
#  'tragiques',
#  'entrent',
#  'août',
#  'Nicolas',
#  'réductions',
#  'adhésion',
#  'célébrités',
#  'libérale',
#  'craignons',
#  'ennemis',
#  'structurels',
#  'analyses',
#  'donnerait',
#  'posée',
#  'étende',
#  'poisson',
#  'obtiens',
#  'pans',
#  'adolescent',
#  'principauté',
#  'consommation',
#  'prend',
#  'estimer',
#  'sièges',
#  'soupçon',
#  'Espagnols',
#  'déclenchez',
#  'croissance',
#  'ancien',
#  'Rapport',
#  'continue',
#  'finno',
#  'subsister',
#  'Katiforis',
#  'unités',
#  'FSE',
#  'dissuasion',
#  'référendums',
#  'menait',
#  'handicaps',
#  'valable',
#  'lacunes',
#  'Dont',
#  'bouleversé',
#  'organiser',
#  'lundi',
#  'pèlerinage',
#  'héritage',
#  'carbone',
#  'abordait',
#  'traversons',
#  '45',
#  'vrai',
#  'italiens',
#  'condamné',
#  'incroyable',
#  'achète',
#  'centralisé',
#  'tergiversations',
#  'notion',
#  'menacée',
#  'Apprendre',
#  'faisant',
#  'chars',
#  'soumets',
#  'voyager',
#  'engageaient',
#  'appuient',
#  'part',
#  'six',
#  'remèdes',
#  'Roth',
#  'divisée',
#  'signe',
#  'immédiatement',
#  'strictes',
#  '9,6',
#  'réduisent',
#  'thèmes',
#  'charte',
#  'travaillent',
#  'Amérique',
#  'chatouilles',
#  'devoirs',
#  'évolutif',
#  'rejetons',
#  'élites',
#  'gazoducs',
#  'astrolabe',
#  'fragile',
#  'appellent',
#  'patriotisme',
#  'enfin',
#  'inquiétude',
#  'avance',
#  'prochainement',
#  'elle‑même',
#  'classifiées',
#  'fossiles',
#  'existeras',
#  'interruption',
#  'entretenu',
#  '‘',
#  'final',
#  'drogues',
#  'mauvaise',
#  'compte-t-il',
#  'Serbie',
#  'constituerait',
#  'car',
#  'demandez',
#  '7ème',
#  'autoréalisatrice',
#  'Soyons',
#  'Monsieur',
#  'Baronne',
#  'chimie',
#  'procédures',
#  'chantage',
#  'présentées',
#  'Air',
#  'visites',
#  'cahier',
#  'baissait',
#  'allégement',
#  'taillée',
#  'Salonique',
#  'FMI',
#  'convaincue',
#  'Cousteau',
#  'Ferreira',
#  'balayer',
#  'marier',
#  'qualifier',
#  'prévoyait',
#  'répande',
#  'grammaire',
#  'misant',
#  'portait',
#  'hygiène',
#  'favorisant',
#  'dangereuse',
#  'congressiste',
#  'éliminer',
#  'impliquée',
#  'Apparemment',
#  'irresponsabilité',
#  'découverte',
#  'rapidement',
#  'introduit',
#  'enregistreur',
#  'doivent',
#  'Troisièmement',
#  'aile',
#  'bonus',
#  'faite',
#  'décennie',
#  'extraordinaires',
#  'raffinage',
#  'turco',
#  'tués',
#  'aviver',
#  'papillon',
#  'défilera',
#  'élève',
#  'volts',
#  'ajustements',
#  'nationalisée',
#  'devrions',
#  'plat',
#  'privatisation',
#  'incisions',
#  'inéluctable',
#  'opérationnelle',
#  'ardu',
#  'nappe',
#  'chacun',
#  'canadien',
#  'inexploitées',
#  'allions',
#  'prévoient',
#  'fleur',
#  'artiste',
#  'écologiques',
#  'différer',
#  'logiciels',
#  'Abruzzes',
#  'gens',
#  'aujourd’hui',
#  'conclusion',
#  'combler',
#  'suscite',
#  'incomplète',
#  'est-elle',
#  'Monde',
#  'Outre',
#  'sidérurgiques',
#  'générique',
#  'garantissent',
#  'postérité',
#  'sécuritaires',
#  'ralliée',
#  'Ouganda',
#  'judicieuse',
#  'appréciation',
#  'réelles',
#  'Eu',
#  'délégués',
#  'minute',
#  'mort',
#  'provenaient',
#  'réglementant',
#  'attiré',
#  'Larive',
#  'tentent',
#  'homozygote',
#  'manières',
#  'cours',
#  'déformé',
#  'excédent',
#  'manifestés',
#  'menacés',
#  'atriums',
#  'cinquante',
#  'mépris',
#  'gagneront',
#  'OLAF',
#  'bouger',
#  'insatisfaites',
#  'Notre',
#  'abordés',
#  'bovines',
#  'atomique',
#  'voudront',
#  'agresseur',
#  'transférables',
#  'iront',
#  'modification',
#  'stipulant',
#  'Moura',
#  'prochains',
#  'cristalline',
#  'Loren',
#  'empathie',
#  'foyers',
#  'israéliennes',
#  'économiquement',
#  'ingénieux',
#  'sollicitent',
#  'Sunlight',
#  'humaines',
#  'allais',
#  'leurs',
#  'élémentaire',
#  'tri',
#  'recrutés',
#  'révèlent',
#  'antérieure',
#  'environnements',
#  'terminale',
#  'attendez',
#  'danoise',
#  'besoin',
#  'Superman',
#  'convergence',
#  'nageoires',
#  'contestées',
#  'dernière',
#  'ingéniosité',
#  'Anatomie',
#  'Nunca',
#  'préconisée',
#  'devienne',
#  'préférée',
#  'aboutiront',
#  'possédons',
#  'dictionnaires',
#  'collecter',
#  'scandaleux',
#  'humaine',
#  'Parvanov',
#  'souscrivez',
#  'lancera',
#  'OMT',
#  'inquiètent',
#  'FI',
#  '-il',
#  '2',
#  'agisse',
#  'guidant',
#  'exceptionnel',
#  'emballé',
#  'électrons',
#  'tirés',
#  'publiques',
#  'clan',
#  'femmes',
#  'complaisance',
#  'suédoises',
#  'isolée',
#  'robot',
#  'devînmes',
#  'voile',
#  'prive',
#  'cadeau',
#  'promptement',
#  'quatorze',
#  'défiant',
#  'jugent',
#  'répéter',
#  ';',
#  'attendre',
#  'pur',
#  'agréées',
#  'essais',
#  'anticipe',
#  'relancer',
#  'nordiques',
#  'vieilles',
#  'innovantes',
#  'banque',
#  'Leyla',
#  'exprimés',
#  'Téhéran',
#  'estimés',
#  'bribes',
#  'surpoids',
#  'voter',
#  'Encore',
#  'Jane',
#  'découplées',
#  'devaient',
#  'Attendez',
#  'bénéficiant',
#  'reportée',
#  'Quart',
#  'roumaines',
#  'abouti',
#  'côtières',
#  'impérialiste',
#  'éteints',
#  'dite',
#  'électrochoc',
#  'séjourné',
#  'forcément',
#  'plongée',
#  'mai',
#  'consisterait',
#  'Nicaragua',
#  'indiquant',
#  'depuis',
#  'empreinte',
#  'exerçons',
#  'directrice',
#  'couches',
#  'hydratée',
#  'incluses',
#  'encerclés',
#  'immunité',
#  'plafonds',
#  'bus',
#  'Kirghiz',
#  'accessibles',
#  'publicité',
#  'omissions',
#  'étonnantes',
#  'tombe',
#  'rétrécir',
#  'traverser',
#  'Tsarukyan',
#  'européennes',
#  'privilégié',
#  'contrer',
#  'entachera',
#  'gulf',
#  'demeurant',
#  'professions',
#  'restrictives',
#  'conviennent',
#  'fictifs',
#  'conviendront',
#  'Excusez',
#  'paradoxal',
#  'limitaient',
#  'environnementale',
#  'démènent',
#  'duquel',
#  'paris',
#  'Aubrespy',
#  'rendues',
#  'perçues',
#  'améliorée',
#  'évolue',
#  'achetées',
#  'immanquablement',
#  'colonne',
#  'souci',
#  'censée',
#  'avancerons',
#  'mettaient',
#  'significatif',
#  'conclus',
#  'explose',
#  'apparente',
#  'influencer',
#  'libanais',
#  'paie',
#  'EuroNest',
#  'dollars',
#  'Quadras',
#  'envoyez',
#  'boxe',
#  'habitants',
#  'affectent',
#  'paieront',
#  'quasi',
#  'représentants',
#  'Terre',
#  'État',
#  'Pyrrhus',
#  'moineaux',
#  'ours',
#  'sautent',
#  'représailles',
#  'ambiant',
#  'limitations',
#  'trouvons',
#  'précises',
#  'dépensent',
#  'sponsorisé',
#  'encourus',
#  'pourparlers',
#  'douzaine',
#  'croyants',
#  'adhérera',
#  'Kenya',
#  'arguments',
#  'toutefois',
#  'minéraux',
#  'bataillons',
#  'fleuron',
#  'vins',
#  'constituera',
#  'incité',
#  '1,7',
#  'joint',
#  'cher',
#  'dépourvus',
#  'élu',
#  'démarre',
#  'institutionnelle',
#  'bicyclette',
#  'passez',
#  'contribution',
#  '21',
#  'licenciements',
#  'chantait',
#  'castes',
#  'obliger',
#  'actée',
#  '2018',
#  '29',
#  'reste',
#  'aspect',
#  'emprunter',
#  'Khodorkovsky',
#  'suffisent',
#  'résistance',
#  'Christ',
#  'déclaré',
#  'affleure',
#  'initiale',
#  'absorption',
#  'dotés',
#  'cité',
#  'La',
#  'exempter',
#  'maladies',
#  'salue',
#  'CNIL',
#  'scepticisme',
#  'reprendrais',
#  'habillement',
#  'tabac',
#  'Seconde',
#  'caractère',
#  'Année',
#  'souhaitées',
#  'permet',
#  'marée',
#  '58',
#  'endettement',
#  'ministérielle',
#  'Ensuite',
#  'actuel',
#  'populaire',
#  'Kosovo',
#  'actuellement',
#  'Pâques',
#  'déplacements',
#  'votions',
#  'rejetée',
#  'sérieux',
#  'probable',
#  'chatouille',
#  'chanté',
#  'FPS',
#  'satisfait',
#  'affectant',
#  'confidentielles',
#  'échouer',
#  'passais',
#  'dégringolade',
#  'vin',
#  'sachant',
#  'diplomatique',
#  'queue',
#  'significative',
#  'épaississement',
#  'orientation',
#  'liquidité',
#  'complètement',
#  'honnêtement',
#  'suppression',
#  'initier',
#  'fortunes',
#  'dispersent',
#  'Pékin',
#  'si',
#  'associées',
#  '1961',
#  'matériaux',
#  'incluent',
#  'yens',
#  'Moins',
#  'dus',
#  'rares',
#  'pré',
#  'vivons',
#  'Magdalene',
#  'forum',
#  'sens',
#  'politique',
#  'incidents',
#  'accueillir',
#  'neutralité',
#  'interception',
#  'Sakellariou',
#  'supprimer',
#  'stagnation',
#  'suivre',
#  'négligeables',
#  'allemande',
#  'El',
#  'deviens',
#  'cris',
#  'fossilise',
#  'marges',
#  'Facebook',
#  'range',
#  'mécanisme',
#  'étendue',
#  'risque',
#  'mobiliser',
#  'attribué',
#  'allez',
#  'DEM',
#  'instantané',
#  'périssent',
#  'ecstasy',
#  'professionnelle',
#  'déstabilisé',
#  'grains',
#  'épreuves',
#  'estimations',
#  'formule',
#  'orales',
#  'Conseil',
#  'égards',
#  'déplorable',
#  'classera',
#  'méritocratie',
#  'commun',
#  'respect',
#  'éventuel',
#  'Jusqu’',
#  'découvrir',
#  'nota',
#  'Fourçans',
#  'accordant',
#  'crise',
#  'J.C.',
#  'US',
#  'dense',
#  'mutuelle',
#  'désignera',
#  'thérapeutiques',
#  'étendant',
#  'communément',
#  'mobilières',
#  'confondre',
#  'surchauffe',
#  'vente',
#  'sacrées',
#  'Observatoire',
#  'règlement',
#  'tenez',
#  'permettra',
#  'cordialement',
#  'lord',
#  'fera',
#  'étayer',
#  'pétales',
#  'Algériens',
#  'compétitifs',
#  'affaire',
#  'maitresse',
#  'vérifier',
#  'scotch',
#  'albanaises',
#  'désertification',
#  'ombres',
#  'Institut',
#  'fédéraliste',
#  'extraterrestre',
#  'endroit',
#  'rattraper',
#  'persécution',
#  'améliorer',
#  'personnages',
#  'WITNESS',
#  'emblée',
#  'écoutions',
#  'Âge',
#  'bombe',
#  'McDonnell',
#  'posteriori',
#  'affrontent',
#  'philosophes',
#  'critiquées',
#  'commencerai',
#  'tendent',
#  'Promets',
#  'magazines',
#  'Saro',
#  'reflétés',
#  'Liste',
#  'Boston',
#  'équivoque',
#  'perdent',
#  'certaine',
#  'successeurs',
#  'contrôlable',
#  'Amitabha',
#  'Manuel',
#  'mi-septembre',
#  'résulté',
#  'Mato',
#  'Tumpel',
#  'Lyon',
#  'sous-utilisation',
#  'souffrance',
#  'Wiwa',
#  'démarrer',
#  'publication',
#  'Commerce',
#  'prévaut',
#  'mollahs',
#  'climat',
#  'connaissances',
#  'courtes',
#  'cible',
#  'Dunlop',
#  'répliquer',
#  'omet',
#  'Américaines',
#  'aurons',
#  '11',
#  'débordant',
#  'tireront',
#  'Mandalay',
#  'sous-secrétaire',
#  'oiseaux',
#  'dissuadent',
#  'inclusion',
#  'Baldarelli',
#  'politico',
#  'détecter',
#  '8',
#  'assistance',
#  'îles',
#  'mastiquée',
#  'rempli',
#  'Kan',
#  'morale',
#  'km',
#  'lunettes',
#  'exporter',
#  'maladie',
#  'Hé',
#  'libanaises',
#  'Nombreux',
#  'extrêmes',
#  'essentiels',
#  'Phnom',
#  'entériné',
#  'suivants',
#  'conscription',
#  'Dow',
#  'nécessaire',
#  'contraintes',
#  'Bassaïev',
#  'dues',
#  'annulation',
#  'psychologues',
#  'inutiles',
#  'Casey',
#  'patchwork',
#  'Car',
#  'Murrow',
#  'entendu',
#  'détachement',
#  'vaut',
#  'Wojciechowski',
#  'Bonnet',
#  'recouru',
#  'conventionnels',
#  'centrale',
#  'Collins',
#  'Lacs',
#  'adaptation',
#  'épaissit',
#  'chapitres',
#  'appartenir',
#  'comparaître',
#  'Autre',
#  'ingérence',
#  'ambition',
#  'thermomètre',
#  '1993',
#  'Évita',
#  'enceinte',
#  'façon',
#  'Poutine',
#  'démobiliser',
#  'gène',
#  'requise',
#  'recettes',
#  'orienté',
#  'Lisbonne',
#  'Églises',
#  'invité',
#  'logiciel',
#  'ouvertement',
#  '160',
#  'social-démocratie',
#  'nourriture',
#  'continuons',
#  'aéroports',
#  'coïncidence',
#  'préoccupants',
#  'reprendre',
#  'cliniques',
#  'appartenance',
#  'sortie',
#  'PPP',
#  'préférer',
#  'voyons',
#  'impôts',
#  'abstraction',
#  'Bailey',
#  'penche',
#  'rentrèrent',
#  '16',
#  'produisent',
#  'inanimées',
#  'méprennent',
#  'étau',
#  'énergétiques',
#  'organisations',
#  'transformés',
#  '3820/85',
#  'leader',
#  'admettons',
#  'Dassault',
#  'annoncé',
#  'Vadim',
#  'flotte',
#  'demi',
#  'discrètement',
#  'femelles',
#  'près',
#  'Monétaire',
#  'deviennent',
#  'structure',
#  'berceau',
#  'Barroso',
#  'redondances',
#  'banalise',
#  'prépare',
#  'Laeken',
#  'trouvez',
#  'illusoire',
#  'obtenir',
#  'mutuellement',
#  'céphalopodes',
#  'malades',
#  'obésité',
#  'conditions',
#  'imposant',
#  'pastilles',
#  'avant-postes',
#  'noyer',
#  'entamée',
#  'dérive',
#  'souffrons',
#  'dépendre',
#  'crainte',
#  'V',
#  'Honduras',
#  'domaine',
#  'Wallström',
#  'soviétiques',
#  'ralentissent',
#  'Monfils',
#  'Hiroshima',
#  'jouons',
#  'attendu',
#  'voyions',
#  'sédatives',
#  'taper',
#  'nouveauté',
#  'coopération',
#  'Irlande',
#  'ronchonner',
#  'Mandelson',
#  'course',
#  ...}

# %%
t
# Out:
# [['Mais', 'avec', 'des', 'idées', 'toxiques', 'cette', 'fois', '.'],
#  ['Si',
#   'tu',
#   'as',
#   'vraiment',
#   'du',
#   'temps',
#   'libre',
#   ',',
#   'lis',
#   'un',
#   'livre',
#   '.',
#   'Empruntes',
#   '-',
#   'en',
#   'un',
#   'à',
#   'la',
#   'bibliothèque',
#   'du',
#   'quartier',
#   '.'],
#  ['Comment', 'se', 'peut', '-', 'il', '?'],
#  ['Vous',
#   'remarquerez',
#   'donc',
#   'que',
#   'beaucoup',
#   'des',
#   'symboles',
#   'ressemblent',
#   'à',
#   'des',
#   'images',
#   "d'",
#   'humains',
#   ',',
#   "d'",
#   'insectes',
#   'de',
#   'poissons',
#   ',',
#   "d'",
#   'oiseaux',
#   '.'],
#  ["L'",
#   'Union',
#   'européenne',
#   'a',
#   'présenté',
#   'des',
#   'propositions',
#   'visant',
#   'à',
#   'empêcher',
#   'nos',
#   'systèmes',
#   'financiers',
#   "d'",
#   'être',
#   'utilisés',
#   'pour',
#   'le',
#   'blanchiment',
#   "d'",
#   'argent',
#   'destiné',
#   'à',
#   'financer',
#   'les',
#   'activités',
#   'terroristes',
#   '.'],
#  ['Cet',
#   '«',
#   'aval',
#   '»',
#   'en',
#   'lui',
#   '-',
#   'même',
#   'fut',
#   'presque',
#   'suffisant',
#   'pour',
#   'offrir',
#   'à',
#   'Morales',
#   'la',
#   'présidence',
#   '.'],
#  ['La', 'même', 'idée', 'peut', 'maintenant', 'être', 'développée', '.'],
#  ['Et',
#   'ensuite',
#   ',',
#   'certains',
#   'intellectuels',
#   'connus',
#   'ont',
#   'condamné',
#   'la',
#   'condamnation',
#   'du',
#   'conseil',
#   'de',
#   'l’',
#   'audiovisuel',
#   'en',
#   'estimant',
#   'qu’',
#   'elle',
#   'était',
#   'une',
#   'entrave',
#   'à',
#   'la',
#   'liberté',
#   'd’',
#   'expression',
#   '.',
#   'Personne',
#   'ne',
#   's’',
#   'est',
#   'inquiété',
#   'du',
#   'risque',
#   'd’',
#   'émulation',
#   'd’',
#   'une',
#   'audience',
#   'déjà',
#   'radicalisée',
#   '.'],
#  ["J'",
#   'aimais',
#   'aussi',
#   'les',
#   'sortes',
#   'de',
#   'jeux',
#   'machos',
#   'intellectuels',
#   '.'],
#  ['Le',
#   'rapport',
#   'Andersson',
#   'réclame',
#   'une',
#   'convergence',
#   'sociale',
#   ',',
#   "c'",
#   'est',
#   '-',
#   'à',
#   '-',
#   'dire',
#   "l'",
#   'uniformisation',
#   'du',
#   'système',
#   'au',
#   'sein',
#   'et',
#   'au',
#   'travers',
#   'de',
#   "l'",
#   'UE',
#   '.'],
#  ['Le',
#   'souffle',
#   'du',
#   'changement',
#   'touchera',
#   'encore',
#   'le',
#   'Moyen',
#   '-',
#   'Orient',
#   'qui',
#   'reste',
#   'menacé',
#   'par',
#   'la',
#   'pression',
#   'étrangère',
#   'et',
#   'le',
#   'fondamentalisme',
#   'religieux',
#   '.'],
#  ['Nous',
#   'devons',
#   'également',
#   'intervenir',
#   'plus',
#   'résolument',
#   'pour',
#   'veiller',
#   'à',
#   'ce',
#   'que',
#   'les',
#   'pauvres',
#   'profitent',
#   'véritablement',
#   'du',
#   'commerce',
#   'mondial',
#   '.'],
#  ['Même',
#   'si',
#   'nous',
#   "n'",
#   'avons',
#   'toujours',
#   'pas',
#   'entamé',
#   'les',
#   'négociations',
#   "d'",
#   'accord',
#   ',',
#   'nous',
#   'pouvons',
#   'poursuivre',
#   'et',
#   'nous',
#   'avons',
#   'une',
#   'base',
#   'juridique',
#   '.'],
#  ['♫',
#   'Oh',
#   ',',
#   'vous',
#   'avez',
#   'été',
#   'si',
#   '--',
#   '♫',
#   "C'",
#   'est',
#   'plutôt',
#   'innovant',
#   ',',
#   'non',
#   '?'],
#  ['Tout', 'cela', 'est', 'en', 'jeu', "aujourd'hui", '.'],
#  ['Je',
#   "m'",
#   'y',
#   'suis',
#   'mis',
#   'et',
#   'bien',
#   'sûr',
#   "j'",
#   'ai',
#   'apprécié',
#   "qu'",
#   'il',
#   'compte',
#   'les',
#   '42',
#   'mn',
#   "d'",
#   'exercice',
#   'elliptique',
#   'que',
#   "j'",
#   'ai',
#   'fait',
#   '.',
#   'Ensuite',
#   ',',
#   'il',
#   'a',
#   'voulu',
#   'plus',
#   "d'",
#   'informations',
#   '.'],
#  ['Il', 'a', 'demandé', 'plus', "d'", 'argent', '.'],
#  ["C'", 'est', 'la', 'priorité', 'numéro', 'un', '.'],
#  ['Il', 'employait', '200', 'personnes', '.'],
#  ["S'",
#   'est',
#   '-',
#   'il',
#   'passé',
#   'quoi',
#   'que',
#   'ce',
#   'soit',
#   "d'",
#   'étrange',
#   '?'],
#  ['Malgré',
#   'ces',
#   'menaces',
#   ',',
#   'une',
#   'politique',
#   'européenne',
#   'efficace',
#   'visant',
#   'à',
#   'réduire',
#   'la',
#   'dépendance',
#   'à',
#   'l’',
#   'égard',
#   'de',
#   'l’',
#   'énergie',
#   'russe',
#   'semblerait',
#   'voir',
#   'le',
#   'jour',
#   '.'],
#  ['Il',
#   'est',
#   'vrai',
#   "qu'",
#   'il',
#   "s'",
#   'agit',
#   "d'",
#   'un',
#   'cas',
#   'de',
#   'subsidiarité',
#   ',',
#   'mais',
#   'le',
#   'problème',
#   'actuel',
#   'réside',
#   'dans',
#   'le',
#   'fait',
#   'que',
#   'certains',
#   'pays',
#   'membres',
#   'ne',
#   'parviennent',
#   'pas',
#   'à',
#   'financer',
#   'les',
#   'réseaux',
#   'en',
#   'raison',
#   'de',
#   'leurs',
#   'difficultés',
#   'économiques',
#   '.'],
#  ['Je',
#   'déplore',
#   'toutefois',
#   "l'",
#   'absence',
#   "d'",
#   'une',
#   'proposition',
#   'concernant',
#   'le',
#   'transfert',
#   'du',
#   'siège',
#   'des',
#   'sociétés',
#   '.',
#   "C'",
#   'est',
#   'selon',
#   'moi',
#   ',',
#   'une',
#   'véritable',
#   'lacune',
#   'du',
#   'marché',
#   'intérieur',
#   '.'],
#  ['Le',
#   'respect',
#   'des',
#   'droits',
#   'de',
#   "l'",
#   'homme',
#   'et',
#   'des',
#   'minorités',
#   'constitue',
#   'un',
#   'principe',
#   'de',
#   'base',
#   'de',
#   'toute',
#   'coopération',
#   'européenne',
#   'et',
#   'les',
#   'pays',
#   'qui',
#   'ne',
#   'le',
#   'comprennent',
#   'pas',
#   'ne',
#   'sont',
#   'pas',
#   'les',
#   'bienvenus',
#   'au',
#   'sein',
#   'de',
#   "l'",
#   'UE',
#   '.'],
#  ['Les',
#   'Européens',
#   'ont',
#   'assujetti',
#   'les',
#   'populations',
#   'amérindiennes',
#   'et',
#   'ont',
#   'également',
#   'ramené',
#   ',',
#   'tout',
#   'particulièrement',
#   'dans',
#   'le',
#   'bassin',
#   'des',
#   'Caraïbes',
#   'et',
#   'au',
#   'Brésil',
#   ',',
#   'des',
#   'cargaisons',
#   'massives',
#   "d'",
#   'esclaves',
#   'africains',
#   '.'],
#  ['Dans',
#   'le',
#   'cas',
#   'contraire',
#   ',',
#   'cette',
#   'Commission',
#   'risque',
#   'bien',
#   'de',
#   'perdre',
#   'sa',
#   'légitimité',
#   'démocratique',
#   'avant',
#   'même',
#   'd’',
#   'avoir',
#   'commencé',
#   'ses',
#   'travaux',
#   '.'],
#  ['Le',
#   'mois',
#   'dernier',
#   ',',
#   'juste',
#   'le',
#   'mois',
#   'dernier',
#   ',',
#   'les',
#   'économistes',
#   'de',
#   'la',
#   'LSE',
#   'ont',
#   'examiné',
#   '50',
#   'études',
#   'de',
#   'systèmes',
#   'de',
#   'rémunération',
#   'à',
#   'la',
#   'performance',
#   'dans',
#   'des',
#   'entreprises',
#   '.'],
#  ['Un',
#   'dernier',
#   'point',
#   ',',
#   'qui',
#   'est',
#   'très',
#   'important',
#   ':',
#   'en',
#   'ce',
#   'qui',
#   'concerne',
#   'les',
#   'ressources',
#   ',',
#   'il',
#   'convient',
#   "d'",
#   'allouer',
#   'certaines',
#   'ressources',
#   'à',
#   "l'",
#   'échelon',
#   'de',
#   "l'",
#   'Union',
#   'européenne',
#   '.'],
#  ['Nous',
#   'sommes',
#   'également',
#   'concepteur',
#   'de',
#   'ces',
#   'équipements',
#   '.'],
#  ['Il',
#   'est',
#   'tout',
#   'aussi',
#   'absurde',
#   'que',
#   'le',
#   'gouvernement',
#   'espagnol',
#   'attaque',
#   'le',
#   'parlement',
#   'italien',
#   'et',
#   'lui',
#   'dise',
#   'que',
#   'ses',
#   'députés',
#   'sont',
#   'trop',
#   'payés',
#   '.'],
#  ['Je',
#   'suis',
#   'convaincu',
#   'du',
#   'besoin',
#   'd’',
#   'Europe',
#   ',',
#   'ne',
#   'me',
#   'classez',
#   'plus',
#   'parmi',
#   'les',
#   'anti-européens',
#   '.'],
#  ['Il',
#   'montra',
#   'cette',
#   'radio',
#   ':',
#   'une',
#   'sorte',
#   'de',
#   'réseau',
#   'cristallin',
#   '.',
#   "L'",
#   'ADN',
#   'avait',
#   'donc',
#   'la',
#   'structure',
#   ',',
#   "quoiqu'",
#   'elle',
#   'la',
#   'devait',
#   'probablement',
#   'à',
#   'différentes',
#   'molécules',
#   'portant',
#   'différents',
#   'ensembles',
#   "d'",
#   'instructions',
#   '.'],
#  ['Ils',
#   'veulent',
#   'faire',
#   'croire',
#   "qu'",
#   'il',
#   'est',
#   'meilleur',
#   'que',
#   'le',
#   'meilleur',
#   'traitement',
#   'déjà',
#   'existant',
#   '.'],
#  ['par',
#   'écrit',
#   '.',
#   '-',
#   'Comment',
#   'ne',
#   'pas',
#   'soutenir',
#   'une',
#   'initiative',
#   'visant',
#   'à',
#   'éradiquer',
#   'la',
#   'tuberculose',
#   "d'",
#   'ici',
#   '2050',
#   ',',
#   'encore',
#   'responsable',
#   'de',
#   '2',
#   'millions',
#   'de',
#   'morts',
#   'par',
#   'an',
#   'dans',
#   'le',
#   'monde',
#   '?'],
#  ['Je',
#   'conclurai',
#   ',',
#   'si',
#   'vous',
#   'le',
#   'permettez',
#   ',',
#   'par',
#   'deux',
#   'commentaires',
#   'plutôt',
#   'provocateurs',
#   'à',
#   'propos',
#   'du',
#   'débat',
#   'en',
#   'général',
#   '.'],
#  ['Un', 'autre', 'exemple', ':', 'un', 'peu', 'plus', 'mathématique', '.'],
#  ['Mais',
#   'le',
#   'problème',
#   'selon',
#   'moi',
#   ',',
#   "c'",
#   'est',
#   'que',
#   'les',
#   'obstacles',
#   'sont',
#   'si',
#   'importants',
#   'que',
#   'les',
#   'recherches',
#   'de',
#   'ce',
#   'genre',
#   'sont',
#   'pénalisées',
#   'pour',
#   'des',
#   'raisons',
#   'apparemment',
#   'éthiques',
#   ',',
#   'mais',
#   'qui',
#   'sont',
#   'en',
#   'fait',
#   'tout',
#   'autres',
#   '.'],
#  ['Je',
#   'crois',
#   'que',
#   'le',
#   'vrai',
#   'défi',
#   'n’',
#   'est',
#   'pas',
#   'de',
#   'relancer',
#   'les',
#   'discussions',
#   '.'],
#  ['sauf', "qu'", 'il', 'est', 'censé', 'être', 'marron', '.'],
#  ['Aussi',
#   ',',
#   'quand',
#   'la',
#   'convertibilité',
#   'du',
#   'dollar',
#   'en',
#   'or',
#   'a',
#   'été',
#   'suspendue',
#   ',',
#   'la',
#   'valeur',
#   'de',
#   'ces',
#   'dettes',
#   'a',
#   'explosé',
#   ',',
#   'menaçant',
#   'la',
#   'survie',
#   'de',
#   'maintes',
#   'institutions',
#   '.'],
#  ['Les',
#   'tolérer',
#   ',',
#   'comme',
#   'nous',
#   "l'",
#   'avons',
#   'fait',
#   'jusque',
#   'récemment',
#   ',',
#   'est',
#   'de',
#   'plus',
#   'en',
#   'plus',
#   'dangereux',
#   '.'],
#  ['Nous',
#   'savons',
#   'bien',
#   'sûr',
#   ',',
#   'Monsieur',
#   'le',
#   'Président',
#   'Santer',
#   ',',
#   'que',
#   'la',
#   'Commission',
#   'elle',
#   '-',
#   'même',
#   'ne',
#   'peut',
#   'agir',
#   'dans',
#   'certains',
#   'domaines',
#   'que',
#   'si',
#   'certains',
#   'États',
#   'membres',
#   'le',
#   'permettent',
#   '.'],
#  ["l'",
#   'évaluation',
#   'des',
#   'informations',
#   'sur',
#   'les',
#   'médicaments',
#   'prescrits',
#   'en',
#   'cas',
#   "d'",
#   'urgence',
#   'sanitaire',
#   ',',
#   'en',
#   'particulier',
#   'dans',
#   'des',
#   'situations',
#   'de',
#   'pandémie',
#   ';'],
#  ['Hélas',
#   ',',
#   'comme',
#   "d'",
#   'autres',
#   "l'",
#   'ont',
#   'déjà',
#   'fait',
#   'observer',
#   ',',
#   'la',
#   'Commission',
#   'estime',
#   "qu'",
#   'il',
#   'convient',
#   'de',
#   'reporter',
#   'cette',
#   'interdiction',
#   'de',
#   'deux',
#   'ans',
#   '.'],
#  ['Cela',
#   'vous',
#   'permet',
#   'de',
#   'vivre',
#   ',',
#   'cela',
#   'permet',
#   'à',
#   "n'",
#   'importe',
#   'quel',
#   'organisme',
#   'de',
#   'vivre',
#   '.'],
#  ['Comme',
#   'le',
#   'savent',
#   'tous',
#   'ceux',
#   'qui',
#   'ont',
#   'déjà',
#   'eu',
#   'un',
#   'emploi',
#   'difficile',
#   ',',
#   'débrancher',
#   'l’',
#   'alarme',
#   'et',
#   'se',
#   'cacher',
#   'sous',
#   'une',
#   'couverture',
#   'n’',
#   'est',
#   'pas',
#   'la',
#   'solution',
#   '.'],
#  ['Les',
#   'autres',
#   'États',
#   'membres',
#   'couvrent',
#   'le',
#   'manque',
#   'à',
#   'gagner',
#   '.'],
#  ['Il',
#   'lui',
#   'fallait',
#   'donc',
#   ',',
#   "d'",
#   'une',
#   'manière',
#   'ou',
#   "d'",
#   'une',
#   'autre',
#   ',',
#   'se',
#   'débarrasser',
#   'de',
#   'deux',
#   'tumeurs',
#   'avant',
#   'de',
#   'pouvoir',
#   'recevoir',
#   'de',
#   "l'",
#   'aide',
#   '.'],
#  ['La',
#   'Russie',
#   'peut',
#   'toujours',
#   'adhérer',
#   'à',
#   "l'",
#   'OMC',
#   'avant',
#   'la',
#   'fin',
#   'de',
#   '2011',
#   'si',
#   'elle',
#   'est',
#   'capable',
#   'de',
#   'prendre',
#   'les',
#   'décisions',
#   'nécessaires',
#   'pour',
#   'résoudre',
#   'les',
#   'quelques',
#   'problèmes',
#   'qui',
#   'demeurent',
#   'au',
#   'niveau',
#   'multilatéral',
#   '.'],
#  ['De',
#   'même',
#   ',',
#   'un',
#   'best-seller',
#   'chinois',
#   'récent',
#   ',',
#   'intitulé',
#   'A',
#   'Survey',
#   'of',
#   'Chinese',
#   'Peasants',
#   ',',
#   'révèle',
#   'les',
#   'coûts',
#   'humains',
#   'astronomiques',
#   'de',
#   "l'",
#   'incitation',
#   'à',
#   'la',
#   'modernisation',
#   'de',
#   'la',
#   'Chine',
#   '.'],
#  ['Je',
#   'trouve',
#   'que',
#   "c'",
#   'est',
#   'difficile',
#   'à',
#   'accepter',
#   ',',
#   'surtout',
#   'lorsque',
#   'le',
#   'travail',
#   'frontalier',
#   'est',
#   'concerné',
#   '.'],
#  ['Si',
#   'le',
#   'Parlement',
#   'parvient',
#   'à',
#   'la',
#   'conclusion',
#   'que',
#   'la',
#   'réglementation',
#   'en',
#   'vigueur',
#   'doit',
#   'être',
#   'modifiée',
#   'ou',
#   "qu'",
#   'une',
#   'nouvelle',
#   'réglementation',
#   'est',
#   'nécessaire',
#   ',',
#   'la',
#   'Commission',
#   'examinera',
#   'attentivement',
#   'ces',
#   'conclusions',
#   'et',
#   ',',
#   'si',
#   'elle',
#   'les',
#   'partage',
#   ',',
#   'prendra',
#   'les',
#   'initiatives',
#   'qui',
#   "s'",
#   'imposent',
#   '.'],
#  ['Avec',
#   'votre',
#   'accord',
#   ',',
#   'je',
#   'vais',
#   'interrompre',
#   'la',
#   'procédure',
#   'de',
#   '"',
#   'carton',
#   'bleu',
#   '"',
#   ',',
#   'en',
#   'dépit',
#   'des',
#   'trois',
#   'demandes',
#   'encore',
#   'insatisfaites',
#   '.'],
#  ['Ces', 'abus', 'persistent', '.'],
#  ['Le',
#   'prix',
#   "d'",
#   'achat',
#   'aurait',
#   'pu',
#   'augmenter',
#   ',',
#   'certes',
#   ',',
#   'mais',
#   'le',
#   'prix',
#   'du',
#   'kilomètre',
#   'parcouru',
#   'aurait',
#   'finalement',
#   'été',
#   'moindre',
#   '.'],
#  ['Près',
#   'de',
#   '60',
#   'ans',
#   'après',
#   'la',
#   'Shoah',
#   ',',
#   'il',
#   'est',
#   'malvenu',
#   'd’',
#   'agiter',
#   'le',
#   'spectre',
#   'de',
#   'cette',
#   'sombre',
#   'page',
#   'de',
#   'l’',
#   'Histoire',
#   '.'],
#  ['Elle',
#   'adopte',
#   'un',
#   'ton',
#   'moins',
#   'catégorique',
#   'que',
#   'je',
#   "l'",
#   'espérais',
#   'mais',
#   'cette',
#   'résolution',
#   ',',
#   'votée',
#   'par',
#   'le',
#   'Parlement',
#   'à',
#   'une',
#   'écrasante',
#   'majorité',
#   ',',
#   'pourrait',
#   'peser',
#   'plus',
#   'sur',
#   'Israël',
#   'et',
#   'le',
#   'Hamas',
#   'que',
#   'les',
#   'résolutions',
#   'indépendantes',
#   "d'",
#   'un',
#   'groupe',
#   'politique',
#   '.'],
#  ['Que',
#   'cela',
#   'nous',
#   'plaise',
#   'ou',
#   'non',
#   ',',
#   'c’',
#   'est',
#   'la',
#   'vérité',
#   '.'],
#  ['On',
#   'la',
#   'fabrique',
#   'en',
#   'déposant',
#   'des',
#   'couches',
#   "d'",
#   'environ',
#   '4',
#   'microns',
#   '.'],
#  ["C'",
#   'est',
#   'la',
#   'même',
#   'personne',
#   '--',
#   'en',
#   'haut',
#   ',',
#   'James',
#   ',',
#   'en',
#   'bas',
#   ',',
#   'Julia',
#   '.'],
#  ['Elle', 'parle', 'aussi', 'le', 'français', '.'],
#  ['Il', 'entra', 'en', 'courant', 'dans', 'la', 'pièce', '.'],
#  ['Ce', 'sont', 'mes', 'CDs', '.'],
#  ['Elle',
#   'avait',
#   'trouvé',
#   'en',
#   'Bush',
#   'un',
#   'allié',
#   'à',
#   'cette',
#   'cause',
#   '.'],
#  ["C'",
#   'est',
#   'la',
#   'même',
#   'montre',
#   'que',
#   'celle',
#   'que',
#   "j'",
#   'ai',
#   'perdue',
#   'il',
#   'y',
#   'a',
#   'une',
#   'semaine',
#   '.'],
#  ['Il',
#   'faut',
#   'combler',
#   'le',
#   'fossé',
#   'numérique',
#   'et',
#   "s'",
#   'assurer',
#   'que',
#   'tous',
#   'les',
#   'citoyens',
#   'européens',
#   'auront',
#   'une',
#   'connexion',
#   'à',
#   'haut',
#   'débit',
#   "d'",
#   'ici',
#   '2020',
#   '.'],
#  ['Dans',
#   'JeuneMoiMaintenantMoi',
#   'on',
#   'demandait',
#   'aux',
#   'gens',
#   'de',
#   'trouver',
#   'une',
#   'photo',
#   "d'",
#   'eux',
#   'mêmes',
#   'quand',
#   'ils',
#   'étaient',
#   'enfants',
#   'et',
#   'de',
#   'la',
#   'recréer',
#   'en',
#   'tant',
#   "qu'",
#   'en',
#   "qu'",
#   'adulte',
#   '.'],
#  ['Ils',
#   'permettent',
#   'à',
#   'près',
#   'de',
#   '15',
#   'millions',
#   'de',
#   'travailleurs',
#   "d'",
#   'être',
#   'informés',
#   'et',
#   'consultés',
#   'non',
#   'seulement',
#   'au',
#   'niveau',
#   'local',
#   ',',
#   'mais',
#   'également',
#   'au',
#   'niveau',
#   'européen',
#   'et',
#   'même',
#   'mondial',
#   '.'],
#  ['Son', 'visage', 'pâlit', '.'],
#  ['Pendant',
#   'cette',
#   'présentation',
#   ',',
#   "j'",
#   'ai',
#   'mentionné',
#   'plusieurs',
#   'fois',
#   'le',
#   'cas',
#   'de',
#   "l'",
#   'Ouganda',
#   ',',
#   'et',
#   'le',
#   'fait',
#   'que',
#   "c'",
#   'est',
#   'le',
#   'seul',
#   'pays',
#   "d'",
#   'Afrique',
#   'sub-saharienne',
#   'à',
#   'avoir',
#   'eu',
#   'des',
#   'succès',
#   '.'],
#  ['Et',
#   'ces',
#   'femmes',
#   'chantent',
#   'une',
#   'chanson',
#   'enchanteresse',
#   ',',
#   'une',
#   'chanson',
#   'si',
#   'séduisante',
#   'que',
#   'tous',
#   'les',
#   'marins',
#   'qui',
#   "l'",
#   'entendent',
#   "s'",
#   'écrasent',
#   'sur',
#   'les',
#   'rochers',
#   'et',
#   'périssent',
#   '.',
#   '»',
#   'On',
#   "s'",
#   'attendrait',
#   ',',
#   'étant',
#   'donné',
#   'cela',
#   ',',
#   "qu'",
#   'ils',
#   'choisissent',
#   'un',
#   'autre',
#   'itinéraire',
#   'pour',
#   'contourner',
#   'les',
#   'Sirènes',
#   ',',
#   'mais',
#   'au',
#   'lieu',
#   'de',
#   'ça',
#   ',',
#   'Ulysse',
#   'dit',
#   ',',
#   '«',
#   'Je',
#   'veux',
#   'entendre',
#   'cette',
#   'chanson',
#   '.'],
#  ['Et',
#   'elle',
#   'a',
#   'ajouté',
#   '"',
#   'Pas',
#   'une',
#   'de',
#   'nos',
#   'filles',
#   '.',
#   '"'],
#  ['En',
#   'passant',
#   'de',
#   '0.1',
#   'à',
#   '0.2',
#   'secondes',
#   ',',
#   'ça',
#   'chatouille',
#   'plus',
#   'à',
#   'la',
#   'fin',
#   '.'],
#  ['Il',
#   'y',
#   'a',
#   'trois',
#   'ans',
#   ',',
#   'les',
#   'beaux',
#   '-',
#   'fils',
#   'de',
#   'Saddam',
#   'Hussein',
#   ',',
#   'Hussein',
#   'et',
#   'Saddam',
#   'Kamil',
#   ',',
#   'se',
#   'sont',
#   'enfuis',
#   'en',
#   'Jordanie',
#   '.'],
#  ['Elles',
#   'apparaissent',
#   'en',
#   'page',
#   'cinq',
#   'du',
#   'rapport',
#   'et',
#   'je',
#   'ne',
#   'vais',
#   'pas',
#   'vous',
#   'les',
#   'lire',
#   '.'],
#  ['Elle', 'est', 'prête', 'à', 'partir', '.'],
#  ['Je',
#   'voudrais',
#   'simplement',
#   'émettre',
#   'un',
#   'commentaire',
#   'sur',
#   'la',
#   'comparaison',
#   'avec',
#   'la',
#   'pomme',
#   '.'],
#  ['Chaque',
#   'fois',
#   'que',
#   'vous',
#   'm’',
#   'entendez',
#   'à',
#   'la',
#   'télévision',
#   'ou',
#   'autre',
#   'part',
#   ',',
#   'J’',
#   'improvise',
#   '.'],
#  ['Celui',
#   '-',
#   'ci',
#   '-',
#   'vous',
#   'pouvez',
#   'voir',
#   'que',
#   'nous',
#   'avons',
#   'marqué',
#   'les',
#   'deux',
#   'requins',
#   'au',
#   'large',
#   'de',
#   'Kerry',
#   '-'],
#  ['PARIS',
#   '-',
#   'Les',
#   'responsables',
#   'politiques',
#   'mondiaux',
#   'se',
#   'félicitent',
#   'régulièrement',
#   "d'",
#   'avoir',
#   'évité',
#   ',',
#   'pendant',
#   'la',
#   'crise',
#   'financière',
#   'qui',
#   'a',
#   'débuté',
#   'en',
#   '2008',
#   ',',
#   'les',
#   'erreurs',
#   'politiques',
#   'des',
#   'années',
#   '1930',
#   '.'],
#  ['Monsieur',
#   'le',
#   'Président',
#   ',',
#   'Monsieur',
#   'Bösch',
#   ',',
#   'Mesdames',
#   'et',
#   'Messieurs',
#   'les',
#   'Députés',
#   ',',
#   'je',
#   'souhaite',
#   "d'",
#   'abord',
#   'vous',
#   'remercier',
#   ',',
#   'Monsieur',
#   'Bösch',
#   ',',
#   'pour',
#   'le',
#   'soutien',
#   'que',
#   'vous',
#   'exprimez',
#   'dans',
#   'votre',
#   'rapport',
#   'et',
#   'que',
#   'vous',
#   'venez',
#   'encore',
#   'une',
#   'fois',
#   "d'",
#   'exprimer',
#   '.'],
#  ['Nous',
#   'réfléchissons',
#   'beaucoup',
#   'à',
#   'ce',
#   'qui',
#   'fait',
#   'vraiment',
#   'marcher',
#   'la',
#   'science',
#   '.'],
#  ['Vous', 'douchez', '-', 'vous', 'quotidiennement', '?'],
#  ['Cela',
#   'reviendrait',
#   'à',
#   'centraliser',
#   'les',
#   'fonds',
#   'consacrés',
#   'à',
#   'la',
#   'recherche',
#   'dans',
#   'un',
#   'seul',
#   'projet',
#   'européen',
#   'et',
#   'à',
#   'réduire',
#   'les',
#   'possibilités',
#   'de',
#   'financement',
#   'ouvertes',
#   'aux',
#   'entreprises',
#   'privées',
#   '.'],
#  ['Il',
#   'sera',
#   'très',
#   'enrichissant',
#   'pour',
#   'la',
#   'Commission',
#   'de',
#   'suivre',
#   'les',
#   'différentes',
#   'orientations',
#   "qu'",
#   'elle',
#   'pourrait',
#   'recevoir',
#   'afin',
#   'de',
#   'présenter',
#   ',',
#   'en',
#   'définitive',
#   ',',
#   'un',
#   'texte',
#   'susceptible',
#   'de',
#   'satisfaire',
#   'tout',
#   'le',
#   'monde',
#   '.'],
#  ['Lorsque',
#   'nous',
#   'parviendra',
#   'le',
#   'rapport',
#   'de',
#   'la',
#   'Commission',
#   ',',
#   'nous',
#   'serons',
#   'en',
#   'mesure',
#   'de',
#   'voir',
#   "jusqu'",
#   'à',
#   'quel',
#   'point',
#   'ces',
#   'niveaux',
#   'de',
#   'limitation',
#   ',',
#   'précisément',
#   'en',
#   'mer',
#   'du',
#   'Nord',
#   'et',
#   'en',
#   'mer',
#   'Baltique',
#   ',',
#   'influent',
#   'sur',
#   'un',
#   'transfert',
#   'du',
#   'transport',
#   'maritime',
#   'au',
#   'transport',
#   'routier',
#   '.'],
#  ['Étant',
#   'donné',
#   'que',
#   'les',
#   'protocoles',
#   'sont',
#   'annexés',
#   'aux',
#   'accords',
#   '-',
#   'cadres',
#   ',',
#   'leur',
#   'renouvellement',
#   'périodique',
#   'ne',
#   'nécessite',
#   'aucune',
#   'nouvelle',
#   'directive',
#   'de',
#   'négociation',
#   '.'],
#  ['Donc',
#   ',',
#   'de',
#   'vastes',
#   'investissements',
#   'pour',
#   'les',
#   'services',
#   'énergétiques',
#   'sont',
#   'à',
#   "l'",
#   'ordre',
#   'du',
#   'jour',
#   'à',
#   'travers',
#   'le',
#   'monde',
#   'en',
#   'développement',
#   '.'],
#  ['Je',
#   'ne',
#   'considère',
#   'pas',
#   'comme',
#   'absurde',
#   'que',
#   "l'",
#   'on',
#   'augmente',
#   'la',
#   'part',
#   "d'",
#   'autofinancement',
#   'de',
#   "l'",
#   'agriculture',
#   '.'],
#  ['À',
#   'mon',
#   'sens',
#   ',',
#   'le',
#   'rapport',
#   'que',
#   'vous',
#   'avez',
#   'sous',
#   'les',
#   'yeux',
#   'est',
#   'constructif',
#   ',',
#   'mais',
#   'pas',
#   'naïf',
#   '.'],
#  ['Le',
#   'riz',
#   'doré',
#   'possède',
#   'un',
#   'potentiel',
#   'd’',
#   'amélioration',
#   'de',
#   'la',
#   'santé',
#   'humaine',
#   'et',
#   'de',
#   'son',
#   'bien-être',
#   'aussi',
#   'monumental',
#   'que',
#   'la',
#   'découverte',
#   'et',
#   'la',
#   'distribution',
#   'du',
#   'vaccin',
#   'de',
#   'Salk',
#   'contre',
#   'la',
#   'polio',
#   '.'],
#  ['Je',
#   'pense',
#   'ici',
#   'à',
#   'une',
#   'économie',
#   'basée',
#   'sur',
#   "l'",
#   'hydrogène',
#   'solaire',
#   ',',
#   'qui',
#   'serait',
#   'un',
#   'réel',
#   'défi',
#   'pour',
#   'ce',
#   'continent',
#   'et',
#   'même',
#   'pour',
#   'la',
#   'communauté',
#   'internationale',
#   '.'],
#  ['Or',
#   ',',
#   'ces',
#   'calculs',
#   'ne',
#   'concordent',
#   'pas',
#   'avec',
#   'les',
#   'récentes',
#   'estimations',
#   'pour',
#   'un',
#   'taux',
#   "d'",
#   'émissions',
#   'de',
#   'CO2',
#   'raisonnable',
#   'et',
#   'acceptable',
#   'calculées',
#   'par',
#   'le',
#   'Groupe',
#   'intergouvernemental',
#   'sur',
#   'l’',
#   'évolution',
#   'du',
#   'climat',
#   '(',
#   'le',
#   'GIEC',
#   ')',
#   'des',
#   'Nations',
#   'Unies',
#   '.'],
#  ["L'", 'Europe', 'a', 'connu', 'la', 'guerre', '.'],
#  ['Le', 'sentiment', 'de', 'panique', 's’', 'est', 'dissipé', '.'],
#  ['Est',
#   '-ce',
#   "qu'",
#   'il',
#   'y',
#   'a',
#   'quelque',
#   'chose',
#   'qui',
#   'ne',
#   'va',
#   'pas',
#   'avec',
#   'moi',
#   '?'],
#  ['Cela',
#   'changerait',
#   '-',
#   'il',
#   'les',
#   'capacités',
#   'du',
#   'chirurgien',
#   '?'],
#  ['Donc',
#   ',',
#   'je',
#   'me',
#   'suis',
#   'remis',
#   'à',
#   'faire',
#   'des',
#   'choses',
#   '.',
#   "C'",
#   'était',
#   'une',
#   'autre',
#   'série',
#   "d'",
#   'objets',
#   'faits',
#   'de',
#   'vieux',
#   'ordinateurs',
#   'de',
#   'ma',
#   'cave',
#   '.'],
#  ["C'",
#   'est',
#   'peut',
#   '-',
#   'être',
#   'une',
#   'bonne',
#   'nouvelle',
#   'pour',
#   'les',
#   'réfugiés',
#   'du',
#   'Darfour',
#   'et',
#   'des',
#   'pays',
#   'voisins',
#   '.'],
#  ['Dans',
#   'ce',
#   'domaine',
#   'également',
#   ',',
#   'je',
#   'le',
#   'répète',
#   ',',
#   "j'",
#   'attends',
#   'du',
#   'Parlement',
#   'européen',
#   "qu'",
#   'il',
#   'exprime',
#   'ses',
#   'desiderata',
#   'lors',
#   'de',
#   'la',
#   'structuration',
#   'du',
#   'deuxième',
#   'pilier',
#   '.'],
#  ['Il',
#   'a',
#   'échangé',
#   'sa',
#   'place',
#   'avec',
#   'la',
#   'personne',
#   'suivante',
#   '.'],
#  ['Ces',
#   'enfants',
#   'ne',
#   'développent',
#   'pas',
#   'plus',
#   'que',
#   "d'",
#   'autres',
#   'enfants',
#   'des',
#   'tendances',
#   'homosexuelles',
#   '.'],
#  ['Monsieur',
#   'le',
#   'Président',
#   ',',
#   'venant',
#   'de',
#   'Londres',
#   ',',
#   'je',
#   'ne',
#   'peux',
#   ',',
#   'en',
#   'aucun',
#   'cas',
#   ',',
#   'minimiser',
#   'la',
#   'menace',
#   'terroriste',
#   '.'],
#  ['Et', 'ça', 'va', 'certainement', 'dans', 'la', 'bonne', 'direction', '.'],
#  ['Mesdames',
#   'et',
#   'Messieurs',
#   ',',
#   '295',
#   'personnes',
#   'ont',
#   'trouvé',
#   'la',
#   'mort',
#   "d'",
#   'une',
#   'façon',
#   'tragique',
#   'dans',
#   'la',
#   'région',
#   'des',
#   'Abruzzes',
#   'à',
#   'la',
#   'suite',
#   'du',
#   'tremblement',
#   'de',
#   'terre',
#   'le',
#   'plus',
#   'grave',
#   "qu'",
#   'a',
#   'connu',
#   "l'",
#   'Italie',
#   'ces',
#   'dernières',
#   'décennies',
#   '.'],
#  ['Je',
#   'voudrais',
#   'remercier',
#   'très',
#   'sincèrement',
#   'les',
#   'présidents',
#   'des',
#   'groupes',
#   'politiques',
#   'pour',
#   'avoir',
#   'respecté',
#   'les',
#   'temps',
#   'impartis',
#   'et',
#   'pour',
#   'avoir',
#   'mené',
#   'ce',
#   'débat',
#   'de',
#   'manière',
#   'aussi',
#   'efficace',
#   '.'],
#  ['En',
#   'ce',
#   'qui',
#   'concerne',
#   'la',
#   'décision',
#   'de',
#   'débloquer',
#   'une',
#   'force',
#   'de',
#   "l'",
#   'UE',
#   ',',
#   'qui',
#   'a',
#   'été',
#   'prise',
#   'à',
#   'la',
#   'mi-septembre',
#   'par',
#   'le',
#   'Conseil',
#   'de',
#   "l'",
#   'UE',
#   ',',
#   'le',
#   'fait',
#   'que',
#   "l'",
#   'on',
#   'ait',
#   'laissé',
#   'expirer',
#   'le',
#   'délai',
#   'imparti',
#   "m'",
#   'inspire',
#   'une',
#   'certaine',
#   'inquiétude',
#   '.'],
#  ['Elles',
#   'touchent',
#   'essentiellement',
#   'aux',
#   'modalités',
#   'applicables',
#   'en',
#   'matière',
#   'de',
#   'droit',
#   'de',
#   'consultation',
#   'de',
#   'données',
#   'à',
#   'caractère',
#   'personnel',
#   ',',
#   'à',
#   "l'",
#   'entrée',
#   'en',
#   'vigueur',
#   'de',
#   'la',
#   'décision',
#   'et',
#   'au',
#   'statut',
#   'du',
#   'personnel',
#   "d'",
#   'Eurojust',
#   '.'],
#  ['Sur',
#   'cette',
#   'base',
#   ',',
#   'je',
#   'ne',
#   'soutiendrai',
#   'pas',
#   'les',
#   'amendements',
#   '6',
#   'et',
#   '7',
#   '.'],
#  ['Alors',
#   "j'",
#   'ai',
#   'fait',
#   'un',
#   'marché',
#   'avec',
#   'elles',
#   '.',
#   "J'",
#   'ai',
#   'dit',
#   '"',
#   'Bon',
#   ',',
#   'on',
#   'abandonne',
#   'le',
#   'côté',
#   'caritatif',
#   ',',
#   'et',
#   'on',
#   'fait',
#   'marcher',
#   'ça',
#   'comme',
#   'une',
#   'entreprise',
#   'et',
#   'je',
#   'vais',
#   'vous',
#   'aider',
#   '"',
#   '.'],
#  ['Comment', 'cela', 'se', 'fait', '-', 'il', '?'],
#  ['Malheureusement',
#   ',',
#   'la',
#   'Commission',
#   "n'",
#   'a',
#   'délivré',
#   'que',
#   'des',
#   'permis',
#   'temporaires',
#   'à',
#   'cinq',
#   'bateaux',
#   'utilisant',
#   'une',
#   'méthode',
#   'utilisant',
#   'des',
#   'stimuli',
#   'électriques',
#   'pour',
#   'la',
#   'pêche',
#   'des',
#   'soles',
#   '.'],
#  ['À',
#   'diverses',
#   'occasions',
#   ',',
#   'nous',
#   "l'",
#   'avons',
#   'mise',
#   'en',
#   'cause',
#   'mais',
#   "n'",
#   'avons',
#   'jamais',
#   'obtenu',
#   'de',
#   'réponse',
#   'satisfaisante',
#   '.'],
#  ["C'",
#   'est',
#   'une',
#   'signature',
#   'consistante',
#   ',',
#   'et',
#   "c'",
#   'est',
#   'très',
#   'stable',
#   '.'],
#  ['Va',
#   '-',
#   't',
#   '-',
#   'il',
#   'à',
#   "l'",
#   'école',
#   'à',
#   'pied',
#   'ou',
#   'bien',
#   'en',
#   'vélo',
#   '?'],
#  ['Mais',
#   'la',
#   'tendance',
#   'de',
#   'la',
#   'médecine',
#   'est',
#   'en',
#   'réalité',
#   'de',
#   'la',
#   'réduire',
#   'exponentiellement',
#   '.'],
#  ['Maintenant', 'je', "m'", 'en', 'veux', '.'],
#  ['Nous',
#   'sommes',
#   'opposés',
#   'à',
#   'l’',
#   'idée',
#   'd’',
#   'empêcher',
#   'une',
#   'éventuelle',
#   'libéralisation',
#   'des',
#   'services',
#   'd’',
#   'intérêt',
#   'général',
#   'au',
#   'moyen',
#   'de',
#   'dérogations',
#   'à',
#   'la',
#   'directive',
#   'sur',
#   'les',
#   'services',
#   ',',
#   'comme',
#   'a',
#   'tenté',
#   'de',
#   'le',
#   'faire',
#   'le',
#   'ministre',
#   'allemand',
#   'de',
#   'l’',
#   'économie',
#   '.'],
#  ['Une', 'réponse', 'en', 'un', 'mot', 'me', 'suffira', '.'],
#  ['(',
#   'EN',
#   ')',
#   'Comme',
#   'vous',
#   'le',
#   'savez',
#   ',',
#   'nous',
#   'nous',
#   'sommes',
#   'rendus',
#   'à',
#   'votre',
#   'bureau',
#   'la',
#   'semaine',
#   'dernière',
#   'avec',
#   'Maggie',
#   'Hughes',
#   ',',
#   "l'",
#   'une',
#   'des',
#   'innombrables',
#   'courageuses',
#   'victimes',
#   "d'",
#   'acte',
#   'criminel',
#   '.'],
#  ['Mais',
#   'voilà',
#   ',',
#   "c'",
#   'est',
#   'un',
#   'procédé',
#   'appelé',
#   '"',
#   'lecture',
#   'à',
#   'froid',
#   '"',
#   '.'],
#  ['Etant',
#   'partisan',
#   'du',
#   'libre',
#   '-',
#   'échange',
#   'et',
#   'de',
#   'la',
#   'libéralisation',
#   'de',
#   "l'",
#   'économie',
#   ',',
#   "j'",
#   'estime',
#   ',',
#   'en',
#   'ce',
#   'qui',
#   'concerne',
#   'les',
#   'produits',
#   'agricoles',
#   ',',
#   'que',
#   "l'",
#   'on',
#   'ne',
#   'peut',
#   'pas',
#   'passer',
#   "d'",
#   'un',
#   'protectionnisme',
#   'et',
#   "d'",
#   'accords',
#   'internationaux',
#   'de',
#   'type',
#   'dirigiste',
#   'à',
#   'une',
#   'libéralisation',
#   'des',
#   'échanges',
#   '.'],
#  ['Pars', 'maintenant', 'et', 'tu', 'le', 'rattraperas', '.'],
#  ['Donc',
#   ',',
#   'je',
#   'suis',
#   'une',
#   'blogueuse',
#   ',',
#   'ce',
#   'qui',
#   'veut',
#   'probablement',
#   'dire',
#   'des',
#   'choses',
#   'différentes',
#   'pour',
#   'beaucoup',
#   "d'",
#   'entre',
#   'vous',
#   '.'],
#  ['Malheureusement',
#   ',',
#   'comme',
#   'souvent',
#   'par',
#   'le',
#   'passé',
#   ',',
#   'si',
#   'le',
#   'Sinn',
#   'Fein',
#   'IRA',
#   'a',
#   'participé',
#   'aux',
#   'négociations',
#   ',',
#   'il',
#   'n’',
#   'a',
#   'pas',
#   'entrepris',
#   'de',
#   'démarches',
#   'concrètes',
#   '.'],
#  ['Les',
#   'propositions',
#   'que',
#   "j'",
#   'ai',
#   'présentées',
#   'dans',
#   'ce',
#   'rapport',
#   'développent',
#   'un',
#   'certain',
#   'nombre',
#   'de',
#   'points',
#   ',',
#   'en',
#   'allant',
#   'plus',
#   'loin',
#   'que',
#   'ne',
#   'le',
#   'souhaite',
#   'le',
#   'Conseil',
#   '.'],
#  ['Il',
#   'pose',
#   'la',
#   'question',
#   'du',
#   'plafonnement',
#   'et',
#   'de',
#   'la',
#   'modulation',
#   'des',
#   'primes',
#   'par',
#   'des',
#   'critères',
#   'qui',
#   'favoriseraient',
#   "l'",
#   'emploi',
#   ',',
#   'et',
#   'dans',
#   'le',
#   'même',
#   'but',
#   ',',
#   'le',
#   'rééquilibrage',
#   'entre',
#   'productions',
#   'continentales',
#   'et',
#   'productions',
#   'méditerranéennes',
#   '.'],
#  ['Le',
#   'fait',
#   "d'",
#   'impliquer',
#   'les',
#   'membres',
#   'du',
#   'Conseil',
#   'européen',
#   'confère',
#   'immédiatement',
#   'aux',
#   'travaux',
#   'un',
#   'caractère',
#   'plus',
#   'politique',
#   '.'],
#  ['Cependant',
#   ',',
#   'en',
#   'ce',
#   'qui',
#   'concerne',
#   'le',
#   'sperme',
#   ',',
#   "j'",
#   'ai',
#   'des',
#   'doutes',
#   ',',
#   'puisque',
#   'les',
#   'mesures',
#   'dont',
#   'nous',
#   'avons',
#   'entendu',
#   'parler',
#   ',',
#   'comme',
#   'la',
#   'stérilisation',
#   ',',
#   'comme',
#   'son',
#   'nom',
#   "l'",
#   'indique',
#   ',',
#   'le',
#   'rendrait',
#   'inefficace',
#   '.'],
#  ['Les',
#   'chiens',
#   'âgés',
#   'et',
#   'malades',
#   'seraient',
#   'euthanasiés',
#   ';',
#   'les',
#   'autres',
#   'stérilisés',
#   'et',
#   'vaccinés',
#   '.'],
#  ['À',
#   'mes',
#   'yeux',
#   ',',
#   "l'",
#   'objectif',
#   'du',
#   'Parlement',
#   'à',
#   'cet',
#   'égard',
#   'est',
#   'clairement',
#   'exprimé',
#   'dans',
#   "d'",
#   'autres',
#   'articles',
#   '.'],
#  ['Tandis',
#   'que',
#   'de',
#   'nombreuses',
#   'régions',
#   'ont',
#   'souffert',
#   ',',
#   'des',
#   'inondations',
#   'soudaines',
#   'ont',
#   'lessivé',
#   'la',
#   'couche',
#   'arable',
#   ',',
#   'détruisant',
#   'nombre',
#   "d'",
#   'hectares',
#   'de',
#   'pommes',
#   'de',
#   'terre',
#   'et',
#   'ravageant',
#   'les',
#   'cultures',
#   'de',
#   'céréales',
#   '.'],
#  ['Je',
#   'crois',
#   'que',
#   'je',
#   'suis',
#   'devenu',
#   'un',
#   'photographe',
#   'sous-marin',
#   'et',
#   'un',
#   'journaliste',
#   'parce',
#   'que',
#   'je',
#   'suis',
#   'tombé',
#   'amoureux',
#   'de',
#   'la',
#   'mer',
#   'étant',
#   'enfant',
#   '.'],
#  ['Malheureusement',
#   ',',
#   'cela',
#   'touche',
#   "d'",
#   'autres',
#   'nations',
#   'également',
#   '.'],
#  ['WASHINGTON',
#   ',',
#   'DC',
#   '–',
#   'La',
#   'Chine',
#   'a',
#   'bien',
#   'résisté',
#   'à',
#   'la',
#   'Grande',
#   'Récession',
#   '.'],
#  ['L’',
#   'histoire',
#   'nous',
#   'montre',
#   'que',
#   'de',
#   'simples',
#   'promesses',
#   'émises',
#   'par',
#   'les',
#   'pays',
#   'bénéficiaires',
#   'ne',
#   'suffisent',
#   'pas',
#   '.'],
#  ['Il',
#   'existe',
#   'actuellement',
#   '443',
#   'centrales',
#   'nucléaires',
#   'en',
#   'activité',
#   '–',
#   'un',
#   'nombre',
#   'qui',
#   'devait',
#   'doubler',
#   'dans',
#   'les',
#   '15',
#   'prochaines',
#   'années',
#   '.'],
#  ['Que',
#   'cette',
#   'question',
#   'ne',
#   'devrait',
#   'pas',
#   'susciter',
#   "l'",
#   'inquiétude',
#   'des',
#   'citoyens',
#   'et',
#   "qu'",
#   'il',
#   "n'",
#   'existe',
#   'pas',
#   'de',
#   'quantités',
#   'dangereuses',
#   "d'",
#   'uranium',
#   'dans',
#   'ces',
#   'mers',
#   '?'],
#  ['En',
#   'agissant',
#   'de',
#   'la',
#   'sorte',
#   ',',
#   'ils',
#   'ont',
#   'clairement',
#   'montré',
#   "qu'",
#   'ils',
#   'attachent',
#   'plus',
#   "d'",
#   'importance',
#   'aux',
#   'questions',
#   "d'",
#   'ordre',
#   'économique',
#   "qu'",
#   'aux',
#   'droits',
#   'sociaux',
#   'et',
#   'à',
#   'la',
#   'justice',
#   '.'],
#  ['Nous',
#   'y',
#   'arriverons',
#   'en',
#   'nous',
#   'allant',
#   'dans',
#   'sept',
#   'grands',
#   'pays',
#   ',',
#   'en',
#   'obtenant',
#   'leur',
#   'accord',
#   'et',
#   'en',
#   'lançant',
#   'le',
#   'projet',
#   '.'],
#  ['Les',
#   'consommateurs',
#   'européens',
#   'expriment',
#   'des',
#   'exigences',
#   'de',
#   'plus',
#   'en',
#   'plus',
#   'fortes',
#   'en',
#   'matière',
#   'de',
#   'sécurité',
#   'alimentaire',
#   ',',
#   'de',
#   'qualité',
#   'des',
#   'produits',
#   'et',
#   'de',
#   'conditions',
#   'de',
#   'production',
#   '.'],
#  ['Je',
#   'me',
#   'réjouis',
#   'du',
#   'code',
#   'de',
#   'conduite',
#   'destiné',
#   'aux',
#   'commissaires',
#   'et',
#   'de',
#   "l'",
#   'obligation',
#   'de',
#   'fournir',
#   'des',
#   'informations',
#   ',',
#   'y',
#   'compris',
#   'des',
#   'informations',
#   'confidentielles',
#   '.'],
#  ['Le',
#   'premier',
#   'concerne',
#   'les',
#   'violations',
#   'des',
#   'droits',
#   'de',
#   'l’',
#   'homme',
#   'au',
#   'Cachemire',
#   'et',
#   'le',
#   'second',
#   'la',
#   'lutte',
#   'contre',
#   'le',
#   'terrorisme',
#   '.'],
#  ['Parfois',
#   ',',
#   'nous',
#   'ne',
#   'reconnaissons',
#   'pas',
#   'le',
#   'sentiment',
#   "d'",
#   'isolement',
#   "qu'",
#   'ont',
#   'ressenti',
#   'nombre',
#   "d'",
#   'éleveurs',
#   'et',
#   "d'",
#   'autres',
#   'personnes',
#   'vivant',
#   'dans',
#   'les',
#   'régions',
#   'rurales',
#   'en',
#   'raison',
#   'des',
#   'effets',
#   'dévastateurs',
#   'de',
#   'cette',
#   'épizootie',
#   'sur',
#   'un',
#   'plan',
#   'économique',
#   'et',
#   'sur',
#   'encore',
#   'bien',
#   "d'",
#   'autres',
#   'plans',
#   '.'],
#  ['Deuxième',
#   'travail',
#   'préparatoire',
#   ',',
#   'et',
#   'il',
#   'en',
#   'a',
#   'été',
#   'beaucoup',
#   'parlé',
#   ',',
#   'le',
#   'statut',
#   'juridique',
#   'de',
#   "l'",
#   'euro',
#   '.'],
#  ['Il',
#   'est',
#   'important',
#   'que',
#   'ce',
#   'soit',
#   'la',
#   'politique',
#   'la',
#   'meilleure',
#   ',',
#   'et',
#   'non',
#   'pas',
#   'une',
#   'autre',
#   ',',
#   'qui',
#   'nous',
#   'serve',
#   "d'",
#   'exemple',
#   '.'],
#  ['(',
#   'EN',
#   ')',
#   'Monsieur',
#   'le',
#   'Président',
#   ',',
#   'la',
#   'transparence',
#   'à',
#   "l'",
#   'égard',
#   'du',
#   'Parlement',
#   'est',
#   'très',
#   'souvent',
#   'mise',
#   'en',
#   'évidence',
#   'maintenant',
#   'que',
#   'le',
#   'traité',
#   'de',
#   'Lisbonne',
#   'est',
#   'en',
#   'vigueur',
#   '.'],
#  ['Votre', 'nom', 'est', 'en', 'tête', 'de', 'liste', '.'],
#  ['Cela',
#   'est',
#   'particulièrement',
#   'pertinent',
#   'en',
#   'ce',
#   'qui',
#   'concerne',
#   "l'",
#   'utilisation',
#   'de',
#   'dispositifs',
#   'de',
#   'retenue',
#   'pour',
#   'enfants',
#   '.'],
#  ['Pour',
#   'vous',
#   'résumer',
#   'la',
#   'situation',
#   ',',
#   'notre',
#   'rapporteur',
#   'ne',
#   'propose',
#   'pas',
#   'de',
#   'modification',
#   'du',
#   'texte',
#   ',',
#   'mais',
#   'simplement',
#   ',',
#   'après',
#   'les',
#   'votes',
#   ',',
#   'que',
#   'les',
#   'services',
#   'réorganisent',
#   'le',
#   'texte',
#   'final',
#   'tel',
#   "qu'",
#   'il',
#   'vient',
#   'de',
#   'le',
#   'proposer',
#   '.'],
#  ['Jim', "n'", 'est', 'pas', 'avocat', 'mais', 'médecin', '.'],
#  ['Elle',
#   'ne',
#   'perçoit',
#   'pas',
#   'encore',
#   'tout',
#   'à',
#   'fait',
#   'clairement',
#   'comment',
#   'elle',
#   'entend',
#   'résoudre',
#   'cette',
#   'question',
#   ',',
#   'elle',
#   'ne',
#   "s'",
#   'est',
#   'pas',
#   'encore',
#   'penchée',
#   'sur',
#   'ce',
#   'problème',
#   '.'],
#  ["N'",
#   'est',
#   '-ce',
#   'pas',
#   'une',
#   'nécessité',
#   'pour',
#   "l'",
#   'AIDCO',
#   ',',
#   "l'",
#   'organisation',
#   'créée',
#   'par',
#   'la',
#   'Commission',
#   '-',
#   'création',
#   'dont',
#   'nous',
#   'nous',
#   'réjouissons',
#   '-',
#   ',',
#   'de',
#   'renforcer',
#   'les',
#   'capacités',
#   'des',
#   'professions',
#   'médicales',
#   'et',
#   "d'",
#   'éducation',
#   '?'],
#  ['Dites', '-', 'moi', 'où', 'vous', 'êtes', 'allé', '.'],
#  ['Dans',
#   'le',
#   'cas',
#   'contraire',
#   ',',
#   'le',
#   'Mexique',
#   'devra',
#   'se',
#   'battre',
#   'pour',
#   'survivre',
#   'dans',
#   'une',
#   'mer',
#   'infestée',
#   'de',
#   'requins',
#   'lors',
#   'de',
#   'la',
#   'prochaine',
#   'marée',
#   '.'],
#  ['Comment',
#   'pouvons',
#   '-',
#   'nous',
#   'empêcher',
#   'les',
#   'banques',
#   "d'",
#   'utiliser',
#   'ce',
#   'règlement',
#   'pour',
#   'justifier',
#   'une',
#   'augmentation',
#   'de',
#   'la',
#   'tarification',
#   'des',
#   'paiements',
#   'domestiques',
#   'et',
#   'comment',
#   'la',
#   'Commission',
#   'entend',
#   '-',
#   'elle',
#   'contrer',
#   'cette',
#   'proposition',
#   '?'],
#  ['Beaucoup',
#   "d'",
#   'entre',
#   'vous',
#   'ont',
#   'parlé',
#   'de',
#   'la',
#   'Russie',
#   '.'],
#  ['Je',
#   'ne',
#   'pense',
#   'pas',
#   'que',
#   'ces',
#   'problèmes',
#   'puissent',
#   'être',
#   'résolus',
#   'simplement',
#   'par',
#   "l'",
#   'auto',
#   '-',
#   'coordination',
#   'du',
#   'secteur',
#   ',',
#   'eu',
#   'égard',
#   'au',
#   'nombre',
#   'de',
#   'banques',
#   'de',
#   'détail',
#   'et',
#   'aux',
#   'difficultés',
#   "qu'",
#   'elles',
#   'éprouvent',
#   'à',
#   'coordonner',
#   'leurs',
#   'activités',
#   '.'],
#  ['La',
#   'dépréciation',
#   'du',
#   'dollar',
#   'échaffaudée',
#   'par',
#   'la',
#   'Réserve',
#   'Fédérale',
#   'semble',
#   'une',
#   'proposition',
#   'intéressante',
#   'depuis',
#   'une',
#   'perspective',
#   'américaine',
#   ',',
#   'mais',
#   'les',
#   'économies',
#   'latino-américaines',
#   'ne',
#   'peuvent',
#   'et',
#   'ne',
#   'devraient',
#   'pas',
#   'assumer',
#   'le',
#   'poids',
#   'du',
#   'réalignement',
#   'du',
#   'dollar',
#   '.'],
#  ['Nous', 'ne', 'pouvons', 'pas', 'moralement', 'cacher', 'le', 'passé', '.'],
#  ['CNN',
#   'et',
#   'la',
#   'BBC',
#   'ont',
#   'été',
#   'attaqué',
#   'pour',
#   'avoir',
#   'fait',
#   'preuve',
#   'de',
#   'partialité',
#   'en',
#   'relayant',
#   'l',
#   '’',
#   '«',
#   'aspect',
#   'humain',
#   '»',
#   'des',
#   'manifestants',
#   'plutôt',
#   'que',
#   'les',
#   'aspects',
#   'plus',
#   'obscurs',
#   'de',
#   'l’',
#   'insurrection',
#   '.'],
#  ['Cela',
#   'étant',
#   ',',
#   'je',
#   'me',
#   'félicite',
#   'de',
#   'la',
#   'déclaration',
#   'du',
#   'président',
#   'en',
#   'exercice',
#   '.'],
#  ['Rien',
#   'que',
#   'par',
#   'sa',
#   'cohérence',
#   ',',
#   'elle',
#   'pourrait',
#   'fortement',
#   'stimuler',
#   'la',
#   'confiance',
#   'du',
#   'pays',
#   '.'],
#  ['La',
#   'statistique',
#   'indiquant',
#   "qu'",
#   'une',
#   'personne',
#   'sur',
#   'trois',
#   'peut',
#   'avoir',
#   'le',
#   'cancer',
#   'effrayerait',
#   "n'",
#   'importe',
#   'qui',
#   '.'],
#  ['Par',
#   'conséquent',
#   ',',
#   'le',
#   'pourcentage',
#   "d'",
#   'erreurs',
#   'montre',
#   'des',
#   'erreurs',
#   'alors',
#   'que',
#   'ce',
#   "qu'",
#   'il',
#   'convient',
#   "d'",
#   'observer',
#   ',',
#   "c'",
#   'est',
#   'ce',
#   'qui',
#   'est',
#   'à',
#   'la',
#   'base',
#   'de',
#   'celles',
#   '-',
#   'ci',
#   '.'],
#  ['La',
#   'Cour',
#   'préconise',
#   'une',
#   'simplification',
#   'des',
#   'systèmes',
#   'de',
#   'remboursement',
#   'des',
#   'dépenses',
#   'et',
#   "l'",
#   'introduction',
#   'de',
#   'dispositifs',
#   'de',
#   'sanctions',
#   'plus',
#   'efficaces',
#   '.'],
#  ['Montrons',
#   'clairement',
#   'aux',
#   'citoyens',
#   'de',
#   "l'",
#   'UE',
#   'que',
#   'nous',
#   'soutenons',
#   'les',
#   'efforts',
#   'de',
#   'solidarité',
#   'et',
#   "d'",
#   'assistance',
#   'nécessaires',
#   'au',
#   'développement',
#   'des',
#   'programmes',
#   "d'",
#   'emploi',
#   'et',
#   'de',
#   'régénération',
#   'pour',
#   'le',
#   'nouveau',
#   'millénaire',
#   '.'],
#  ['Je',
#   'propose',
#   'donc',
#   'une',
#   'idée',
#   'simple',
#   'et',
#   'pratique',
#   ',',
#   'qui',
#   'a',
#   'un',
#   'précédent',
#   '.'],
#  ['Ce',
#   'rapport',
#   'confirme',
#   'que',
#   'les',
#   'entreprises',
#   'et',
#   'les',
#   'clients',
#   'ne',
#   'bénéficient',
#   'pas',
#   'encore',
#   'd’',
#   'un',
#   'marché',
#   'intérieur',
#   'pleinement',
#   'concurrentiel',
#   'dans',
#   'le',
#   'secteur',
#   'des',
#   'cartes',
#   'bancaires',
#   '.'],
#  ['Nous',
#   'ne',
#   'pouvons',
#   'accepter',
#   'cette',
#   'pression',
#   'continue',
#   'alors',
#   'que',
#   'le',
#   'traité',
#   'a',
#   'été',
#   'rejeté',
#   '.'],
#  ['À',
#   'cet',
#   'égard',
#   ',',
#   "l'",
#   'Année',
#   'européenne',
#   'de',
#   "l'",
#   'égalité',
#   'des',
#   'chances',
#   'pour',
#   'tous',
#   'et',
#   'la',
#   'campagne',
#   "d'",
#   'information',
#   'actuelle',
#   'intitulée',
#   '"',
#   'Pour',
#   'la',
#   'diversité',
#   '.',
#   'Contre',
#   'les',
#   'discriminations',
#   '"',
#   'constituent',
#   ',',
#   'à',
#   'notre',
#   'avis',
#   ',',
#   'des',
#   'instruments',
#   'extrêmement',
#   'utiles',
#   '.'],
#  ['(',
#   'FI',
#   ')',
#   'Madame',
#   'la',
#   'Présidente',
#   ',',
#   'je',
#   'voudrais',
#   ',',
#   'moi',
#   'aussi',
#   ',',
#   'remercier',
#   'le',
#   'rapporteur',
#   'pour',
#   'un',
#   'excellent',
#   'rapport',
#   'très',
#   'équilibré',
#   '.'],
#  ['Au',
#   'niveau',
#   'politique',
#   ',',
#   'la',
#   'France',
#   'et',
#   'ses',
#   'alliés',
#   'sont',
#   'opposés',
#   'au',
#   'concept',
#   "d'",
#   'un',
#   'gouvernement',
#   'continental',
#   'prôné',
#   'à',
#   'la',
#   'fin',
#   'des',
#   'années',
#   '1950',
#   'et',
#   'au',
#   'début',
#   'des',
#   'années',
#   '1960',
#   'par',
#   'des',
#   'individus',
#   'comme',
#   'Nasser',
#   'et',
#   'Nkrumah',
#   '.'],
#  ['Tôt', 'ou', 'tard', ',', 'les', 'otages', 'seront', 'libérés', '.'],
#  ['Est',
#   '-ce',
#   'vraiment',
#   'le',
#   'bon',
#   'signal',
#   'à',
#   'envoyer',
#   ',',
#   'à',
#   'un',
#   'moment',
#   'où',
#   'le',
#   'financement',
#   'alloué',
#   'à',
#   "d'",
#   'autres',
#   'projets',
#   'de',
#   'recherche',
#   ',',
#   'en',
#   'particulier',
#   'dans',
#   'le',
#   'domaine',
#   'de',
#   "l'",
#   'énergie',
#   'renouvelable',
#   ',',
#   'est',
#   'en',
#   'train',
#   "d'",
#   'être',
#   'revu',
#   'à',
#   'la',
#   'baisse',
#   '?'],
#  ['M.',
#   'Solana',
#   ',',
#   'je',
#   'vous',
#   'souhaite',
#   'moi',
#   'aussi',
#   'beaucoup',
#   'de',
#   'succès',
#   '.'],
#  ['Il',
#   'ne',
#   'fait',
#   'donc',
#   'aucun',
#   'doute',
#   'que',
#   'le',
#   'multilinguisme',
#   'est',
#   'un',
#   'objectif',
#   'primordial',
#   'mais',
#   'il',
#   'y',
#   'a',
#   'eu',
#   ',',
#   'récemment',
#   ',',
#   'une',
#   'tendance',
#   'perceptible',
#   ',',
#   'croissante',
#   'et',
#   'inacceptable',
#   'à',
#   'imposer',
#   'une',
#   'seule',
#   'langue',
#   ',',
#   'et',
#   'je',
#   'crois',
#   'qu’',
#   'il',
#   'convient',
#   'de',
#   'nous',
#   'opposer',
#   'à',
#   'cela',
#   '.'],
#  ['Alors',
#   'que',
#   'la',
#   'santé',
#   'de',
#   "l'",
#   'environnement',
#   'dépend',
#   'fortement',
#   'de',
#   'la',
#   'production',
#   'énergétique',
#   ',',
#   'de',
#   'nombreux',
#   'amendements',
#   'du',
#   'Parlement',
#   'tentent',
#   "d'",
#   'améliorer',
#   'la',
#   'recherche',
#   'sur',
#   'les',
#   'nouvelles',
#   'formes',
#   "d'",
#   'énergie',
#   'renouvelable',
#   '.'],
#  ['Il', "n'", 'y', 'a', 'plus', 'de', 'fossé', '.'],
#  ['Elle',
#   'aime',
#   "l'",
#   'agriculture',
#   'et',
#   'veut',
#   'être',
#   'un',
#   'professeur',
#   'de',
#   'lycée',
#   '.'],
#  ['On',
#   'ne',
#   'tombe',
#   'pas',
#   'amoureux',
#   'de',
#   "quelqu'",
#   'un',
#   'parce',
#   "qu'",
#   'il',
#   'est',
#   'parfait',
#   '.'],
#  ['Et',
#   'je',
#   'sais',
#   "qu'",
#   'il',
#   'y',
#   'a',
#   'des',
#   'réalisateurs',
#   'indépendants',
#   'et',
#   'des',
#   'films',
#   'qui',
#   'pourraient',
#   'faire',
#   'en',
#   'sorte',
#   'que',
#   'ça',
#   'se',
#   'produise',
#   '.'],
#  ['Sans',
#   'un',
#   'effort',
#   'délibéré',
#   'des',
#   'deux',
#   'côtés',
#   'pour',
#   'parvenir',
#   'à',
#   'une',
#   'meilleure',
#   'entente',
#   ',',
#   'le',
#   'monde',
#   'doit',
#   's’',
#   'attendre',
#   'à',
#   'des',
#   'jours',
#   'difficiles',
#   'en',
#   '2011',
#   'et',
#   'au',
#   '-',
#   'delà',
#   '.'],
#  ['La',
#   'promotion',
#   'de',
#   "l'",
#   'idée',
#   'de',
#   'la',
#   'transplantation',
#   'et',
#   'la',
#   'coordination',
#   'de',
#   "l'",
#   'échange',
#   "d'",
#   'expériences',
#   'entre',
#   'les',
#   'États',
#   'membres',
#   'peuvent',
#   'sauver',
#   'des',
#   'milliers',
#   'de',
#   'vie',
#   '.'],
#  ['Nous',
#   'observons',
#   'actuellement',
#   'le',
#   'non-respect',
#   'du',
#   'droit',
#   ',',
#   'comme',
#   'c’',
#   'est',
#   'le',
#   'cas',
#   'pour',
#   'le',
#   'pacte',
#   'de',
#   'stabilité',
#   'et',
#   'de',
#   'croissance',
#   ',',
#   'et',
#   'cela',
#   'me',
#   'mène',
#   'à',
#   'supposer',
#   'que',
#   'les',
#   'rapports',
#   'd’',
#   'évaluation',
#   'ne',
#   'suffiront',
#   'pas',
#   '.'],
#  ['Le',
#   'but',
#   'est',
#   'de',
#   'rendre',
#   'illégale',
#   'une',
#   'décision',
#   'révolutionnaire',
#   'prise',
#   'par',
#   'la',
#   'Cour',
#   'de',
#   'justice',
#   'des',
#   'Communautés',
#   'européennes',
#   'en',
#   'date',
#   'du',
#   '18',
#   'décembre',
#   '2007',
#   '.'],
#  ['Cependant',
#   ',',
#   'Monsieur',
#   'le',
#   'Commissaire',
#   ',',
#   'vous',
#   'avez',
#   'parlé',
#   'de',
#   "l'",
#   'accès',
#   'aux',
#   'capitaux',
#   'comme',
#   "l'",
#   'un',
#   'des',
#   'problèmes',
#   'majeurs',
#   ',',
#   'et',
#   'vous',
#   'avez',
#   'mentionné',
#   'la',
#   'Banque',
#   'européenne',
#   "d'",
#   'investissement',
#   '.'],
#  ['Nous',
#   'ne',
#   'voulons',
#   'plus',
#   'voir',
#   'de',
#   'tels',
#   'accidents',
#   'se',
#   'répéter',
#   '.'],
#  ['(',
#   'RO',
#   ')',
#   'Avant',
#   'tout',
#   ',',
#   'je',
#   'félicite',
#   'le',
#   'rapporteur',
#   ',',
#   'M.',
#   'Rübig',
#   ',',
#   'et',
#   'je',
#   'voudrais',
#   'apporter',
#   'quelques',
#   'précisions',
#   '.'],
#  ['Le',
#   'Conseil',
#   'a',
#   'adopté',
#   "l'",
#   'année',
#   'passée',
#   'le',
#   'programme',
#   'DAPHNE',
#   ',',
#   'un',
#   'nouvel',
#   'instrument',
#   'politique',
#   'pour',
#   'la',
#   'prévention',
#   'de',
#   'toutes',
#   'les',
#   'formes',
#   'de',
#   'violence',
#   '-',
#   'corporelle',
#   ',',
#   'sexuelle',
#   'et',
#   'morale',
#   '-',
#   'contre',
#   'les',
#   'femmes',
#   'et',
#   'les',
#   'enfants',
#   '.'],
#  ['Quand',
#   'le',
#   'Conseil',
#   'compte-t-il',
#   'supprimer',
#   'les',
#   'Moudjahidin',
#   'du',
#   'peuple',
#   'de',
#   'la',
#   'liste',
#   'des',
#   'organisations',
#   'terroristes',
#   '?'],
#  ['Des',
#   'manœuvres',
#   'précises',
#   'des',
#   'mains',
#   'sont',
#   'nécessaires',
#   'pour',
#   'accomplir',
#   'des',
#   'tâches',
#   'délicates',
#   'comme',
#   'celle',
#   '-',
#   'ci',
#   '.'],
#  ['Voilà', 'pourquoi', 'nous', 'déployons', 'ces', 'efforts', '.'],
#  ['Manifestement',
#   ',',
#   'la',
#   'Présidence',
#   'française',
#   'a',
#   'pour',
#   'priorité',
#   "d'",
#   'identifier',
#   'le',
#   'moyen',
#   'de',
#   'résorber',
#   'la',
#   'faille',
#   'irlandaise',
#   'puisque',
#   'le',
#   'processus',
#   'européen',
#   'doit',
#   'se',
#   'poursuivre',
#   'et',
#   'que',
#   'le',
#   'traité',
#   'de',
#   'Nice',
#   'bloque',
#   "l'",
#   'élargissement',
#   '.'],
#  ['Nous',
#   'informerons',
#   'naturellement',
#   'la',
#   'Présidente',
#   'de',
#   'votre',
#   'demande',
#   '.'],
#  ['Les',
#   'sociétés',
#   'allemandes',
#   'investissent',
#   'également',
#   'beaucoup',
#   'dans',
#   'les',
#   'nouveaux',
#   'États',
#   'membres',
#   '.'],
#  ['En',
#   'effet',
#   ',',
#   'l’',
#   'ancien',
#   'président',
#   'de',
#   'Muhammadiyah',
#   ',',
#   'Syafi’',
#   'i',
#   'Ma’',
#   'arif',
#   ',',
#   'a',
#   'développé',
#   'une',
#   'argumentation',
#   'pluraliste',
#   'fondée',
#   'sur',
#   'le',
#   'Coran',
#   'contre',
#   'une',
#   'obéissance',
#   'aveugle',
#   'à',
#   'la',
#   'jurisprudence',
#   'islamique',
#   'classique',
#   '.'],
#  ['Voulons',
#   '-',
#   'nous',
#   'ouvrir',
#   'notre',
#   'marché',
#   'aux',
#   'OGM',
#   'ou',
#   'aux',
#   'viandes',
#   'bovines',
#   'élevées',
#   'aux',
#   'hormones',
#   '?'],
#  ['Il',
#   "s'",
#   'agit',
#   'donc',
#   'là',
#   "d'",
#   'un',
#   'test',
#   'de',
#   'crédibilité',
#   'pour',
#   'la',
#   'politique',
#   'étrangère',
#   'et',
#   'de',
#   'sécurité',
#   'commune',
#   'de',
#   "l'",
#   'Union',
#   '.'],
#  ['Mesdames',
#   'et',
#   'Messieurs',
#   ',',
#   'l’',
#   'Europe',
#   'a',
#   'soutenu',
#   'l’',
#   'initiative',
#   'de',
#   'la',
#   'feuille',
#   'de',
#   'route',
#   '.'],
#  ['Le', 'Parlement', 'ne', 'peut', 'modifier', 'ces', 'particularités', '.'],
#  ['La',
#   'première',
#   'étape',
#   'doit',
#   'être',
#   'la',
#   'libération',
#   'de',
#   'tous',
#   'les',
#   'prisonniers',
#   'politiques',
#   '.'],
#  ['Elles',
#   'représentent',
#   'les',
#   'étendues',
#   'de',
#   "l'",
#   'imagination',
#   'humaine',
#   'qui',
#   'remontent',
#   'à',
#   "l'",
#   'aube',
#   'du',
#   'temps',
#   '.',
#   'Et',
#   'pour',
#   'nous',
#   'tous',
#   ',',
#   'les',
#   'rêves',
#   'de',
#   'ces',
#   'enfants',
#   ',',
#   'comme',
#   'les',
#   'rêves',
#   'de',
#   'nos',
#   'enfants',
#   ',',
#   'deviennent',
#   'une',
#   'partie',
#   'de',
#   'la',
#   'géographie',
#   'à',
#   "l'",
#   'état',
#   'pur',
#   ',',
#   'de',
#   "l'",
#   'espoir',
#   '.'],
#  ['Mais', "c'", 'est', 'un', 'bon', 'rapport', '.'],
#  ['Notre',
#   'langue',
#   'est',
#   'inintelligible',
#   'et',
#   'parfois',
#   'totalement',
#   'incompréhensible',
#   '.',
#   'Nous',
#   'devons',
#   'donc',
#   'être',
#   'capables',
#   'de',
#   'reconnaître',
#   'que',
#   "c'",
#   'est',
#   'là',
#   'un',
#   'problème',
#   'en',
#   'soi',
#   'et',
#   'un',
#   'défi',
#   'en',
#   'soi',
#   ',',
#   'de',
#   'manière',
#   'à',
#   'pouvoir',
#   'nous',
#   'rapprocher',
#   'des',
#   'Européens',
#   '.'],
#  ['Telle',
#   'est',
#   "l'",
#   'une',
#   'des',
#   'méthodes',
#   'en',
#   'vigueur',
#   'pour',
#   'faire',
#   'fonctionner',
#   'la',
#   'mondialisation',
#   'et',
#   'en',
#   'faire',
#   'profiter',
#   'ceux',
#   'qui',
#   'sont',
#   'dans',
#   'le',
#   'besoin',
#   '.'],
#  ['Au',
#   'chapitre',
#   'des',
#   'procédures',
#   ',',
#   'nous',
#   'éprouvons',
#   'une',
#   'certaine',
#   'inquiétude',
#   'quant',
#   'aux',
#   'limites',
#   'à',
#   "l'",
#   'extension',
#   'de',
#   'la',
#   'majorité',
#   'qualifiée',
#   '.'],
#  ['Au',
#   'sujet',
#   'de',
#   "l'",
#   'amendement',
#   '18',
#   'sur',
#   'les',
#   'pouvoirs',
#   "d'",
#   'enquête',
#   'de',
#   'la',
#   'Commission',
#   ',',
#   'cette',
#   'matière',
#   'ne',
#   'relève',
#   'pas',
#   'du',
#   'règlement',
#   'financier',
#   'mais',
#   "d'",
#   'arrangements',
#   'entre',
#   'les',
#   'institutions',
#   '.'],
#  ['En',
# ...
#   'terme',
#   'et',
#   'intégrée',
#   'pour',
#   'chacun',
#   'de',
#   'ces',
#   'trois',
#   'pays',
#   'voisins',
#   '.'],
#  ['Je', "n'", 'ai', 'pas', 'de', 'plan', 'de', 'carrière', '.'],
#  ["J'",
#   'espère',
#   'donc',
#   "qu'",
#   'au',
#   'cours',
#   'de',
#   "l'",
#   'année',
#   'prochaine',
#   ',',
#   'la',
#   'Commission',
#   'consacrera',
#   'davantage',
#   "d'",
#   'énergie',
#   'au',
#   'développement',
#   "d'",
#   'une',
#   'croissance',
#   'respectueuse',
#   'de',
#   "l'",
#   'environnement',
#   '.'],
#  ['Monsieur',
#   'le',
#   'Président',
#   ',',
#   'trois',
#   'brèves',
#   'remarques',
#   'sur',
#   'le',
#   'thème',
#   'du',
#   'cycle',
#   'du',
#   'millénaire',
#   'et',
#   'de',
#   'la',
#   'diversité',
#   'culturelle',
#   '.'],
#  ['Message',
#   'numéro',
#   'trois',
#   ':',
#   'ne',
#   'partez',
#   'pas',
#   'avant',
#   'de',
#   'partir',
#   '.'],
#  ['Le', 'téléviseur', 'ne', 'marche', 'pas', '.'],
#  ['Simplement',
#   'allez',
#   '-',
#   'y',
#   ',',
#   'et',
#   'quoique',
#   'vous',
#   'fassiez',
#   ',',
#   'faites',
#   '-',
#   'le',
#   'au',
#   'mieux',
#   'de',
#   'vos',
#   'capacités',
#   '.'],
#  ['Et',
#   ',',
#   'étant',
#   'donné',
#   'que',
#   'les',
#   'individus',
#   'aux',
#   'sympathies',
#   'islamistes',
#   'qui',
#   'cautionnent',
#   'la',
#   'violence',
#   'sont',
#   'plus',
#   'susceptibles',
#   'que',
#   'd’',
#   'autres',
#   'de',
#   's’',
#   'impliquer',
#   'dans',
#   'le',
#   'terrorisme',
#   'domestique',
#   ',',
#   'seuls',
#   '1,1',
#   '%',
#   'des',
#   'musulmans',
#   'allemands',
#   'relèvent',
#   'de',
#   'cette',
#   'catégorie',
#   '.'],
#  ['Des',
#   'questions',
#   'restent',
#   'en',
#   'suspens',
#   '–',
#   'du',
#   'moins',
#   'dans',
#   'de',
#   'nombreux',
#   'pays',
#   ',',
#   'les',
#   'perspectives',
#   'd’',
#   'une',
#   'reprise',
#   'solide',
#   'sont',
#   'au',
#   'mieux',
#   'à',
#   'un',
#   'ou',
#   'deux',
#   'ans',
#   '.'],
#  ['Il',
#   'a',
#   'de',
#   'bonnes',
#   'raisons',
#   "d'",
#   'être',
#   'très',
#   'en',
#   'colère',
#   '.'],
#  ['Nous', 'pensons', 'toujours', 'que', 'c’', 'est', 'le', 'cas', '.'],
#  ['Je',
#   'salue',
#   'la',
#   'recommandation',
#   'de',
#   'Graham',
#   'Watson',
#   ',',
#   'car',
#   'elle',
#   'promeut',
#   'la',
#   'participation',
#   'de',
#   'la',
#   'Moldavie',
#   'à',
#   'plusieurs',
#   'programmes',
#   'et',
#   'agences',
#   'communautaires',
#   ',',
#   'de',
#   'manière',
#   'à',
#   'soutenir',
#   'les',
#   'efforts',
#   'de',
#   'ce',
#   'pays',
#   'voisin',
#   'en',
#   'vue',
#   'de',
#   'se',
#   'réformer',
#   'et',
#   'de',
#   'se',
#   'moderniser',
#   '.'],
#  ['Monsieur',
#   'le',
#   'Président',
#   ',',
#   'je',
#   'vous',
#   'souhaite',
#   'un',
#   'bon',
#   'appétit',
#   '.',
#   'À',
#   'vous',
#   ',',
#   'ainsi',
#   "qu'",
#   'à',
#   'tous',
#   'les',
#   'interprètes',
#   'et',
#   'fonctionnaires',
#   'qui',
#   'ont',
#   'eu',
#   'la',
#   'patience',
#   'de',
#   'rester',
#   'dans',
#   'la',
#   'salle',
#   'avec',
#   'moi',
#   '.'],
#  ['Nous',
#   'serions',
#   'ravis',
#   'de',
#   'disposer',
#   'de',
#   'davantage',
#   'de',
#   'ressources',
#   ':',
#   'nous',
#   'connaissons',
#   'les',
#   'réalisations',
#   'de',
#   'la',
#   'coopération',
#   'gouvernementale',
#   'en',
#   'rapport',
#   'avec',
#   'les',
#   'objectifs',
#   'de',
#   'Lisbonne',
#   '.'],
#  ['Le',
#   'nombre',
#   'croissant',
#   "d'",
#   'objectifs',
#   'obligatoires',
#   ',',
#   'comme',
#   'la',
#   'législation',
#   'relative',
#   'aux',
#   'émissions',
#   'de',
#   'CO2',
#   ',',
#   'nécessitent',
#   'une',
#   'adaptation',
#   'continue',
#   'de',
#   'la',
#   'part',
#   'de',
#   "l'",
#   'industrie',
#   'automobile',
#   '.'],
#  ['Et',
#   'nous',
#   'sommes',
#   'prêts',
#   'à',
#   'apporter',
#   'davantage',
#   'd’',
#   'aide',
#   '–',
#   'y',
#   'compris',
#   'dans',
#   'le',
#   'cadre',
#   'd’',
#   'un',
#   'nouveau',
#   'mécanisme',
#   'de',
#   'financement',
#   'pour',
#   'les',
#   'pays',
#   'frappés',
#   'par',
#   'des',
#   'chocs',
#   'exogènes',
#   '–',
#   'pour',
#   'aider',
#   'ceux',
#   'que',
#   'la',
#   'crise',
#   'financière',
#   'a',
#   'le',
#   'plus',
#   'gravement',
#   'affectés',
#   '.'],
#  ['Je',
#   'pense',
#   'toutefois',
#   'que',
#   'ma',
#   'position',
#   'centrale',
#   ',',
#   'en',
#   'tant',
#   'que',
#   'modéré',
#   ',',
#   'est',
#   'la',
#   'bonne',
#   '.'],
#  ['Elle', "n'", 'appréciait', 'pas', 'de', 'vivre', 'en', 'ville', '.'],
#  ['La',
#   'plupart',
#   'des',
#   'habitants',
#   'de',
#   'ces',
#   'deux',
#   'petits',
#   'États',
#   'ne',
#   'veulent',
#   'être',
#   'subordonnés',
#   'à',
#   'la',
#   'Géorgie',
#   'en',
#   'aucune',
#   'circonstance',
#   ',',
#   'tout',
#   'comme',
#   'les',
#   'habitants',
#   'du',
#   'Kosovo',
#   'ne',
#   'veulent',
#   'en',
#   'aucune',
#   'circonstance',
#   'dépendre',
#   'de',
#   'la',
#   'Serbie',
#   '.'],
#  ['Nous',
#   'sommes',
#   'restés',
#   'là',
#   '-',
#   'bas',
#   'pendant',
#   'trois',
#   'mois',
#   '.'],
#  ['Il',
#   "s'",
#   'agit',
#   'là',
#   "d'",
#   'une',
#   'condition',
#   'sine',
#   'qua',
#   'non',
#   "d'",
#   'une',
#   'protection',
#   'réelle',
#   'des',
#   'libertés',
#   'individuelles',
#   'des',
#   'citoyens',
#   '.'],
#  ['Ce',
#   'droit',
#   'doit',
#   'en',
#   'premier',
#   'lieu',
#   'être',
#   'garanti',
#   'par',
#   'le',
#   'pays',
#   'vers',
#   'lequel',
#   "l'",
#   'intéressé',
#   'est',
#   'extradé',
#   '.'],
#  ['au',
#   'nom',
#   'du',
#   'groupe',
#   'PSE',
#   '.',
#   '-',
#   'Madame',
#   'la',
#   'Présidente',
#   ',',
#   'je',
#   'remercie',
#   'vivement',
#   'M.',
#   'Kaczmarek',
#   'ainsi',
#   'que',
#   'le',
#   'commissaire',
#   'pour',
#   'ses',
#   'commentaires',
#   'sur',
#   'le',
#   'rapport',
#   '.'],
#  ['Il',
#   'était',
#   ',',
#   'en',
#   'fait',
#   ',',
#   'un',
#   'philosophe',
#   'moral',
#   ',',
#   'et',
#   'il',
#   'avait',
#   'raison',
#   'sur',
#   'ce',
#   'pourquoi',
#   'nous',
#   'sommes',
#   'moraux',
#   '.'],
#  ["J'", 'ai', 'raté', 'le', 'dernier', 'bus', 'hier', '.'],
#  ['La',
#   'plupart',
#   "d'",
#   'entre',
#   'vous',
#   'a',
#   "l'",
#   'air',
#   'intelligent',
#   '.'],
#  ['Cette',
#   'approche',
#   'présuppose',
#   'que',
#   'les',
#   'actifs',
#   'et',
#   'l’',
#   'exposition',
#   'au',
#   'risque',
#   'des',
#   'banques',
#   'puissent',
#   'être',
#   'mesurés',
#   'correctement',
#   '.'],
#  ['La',
#   'réaction',
#   'en',
#   'chaîne',
#   'découlant',
#   'du',
#   'réveil',
#   'des',
#   'nationalismes',
#   'modifie',
#   'dangereusement',
#   'le',
#   'paysage',
#   'politique',
#   '.'],
#  ['La',
#   'différence',
#   "n'",
#   'est',
#   'pas',
#   'bien',
#   'grande',
#   'par',
#   'rapport',
#   'au',
#   'point',
#   'de',
#   'vue',
#   'exprimé',
#   'par',
#   'le',
#   'Conseil',
#   ',',
#   'qui',
#   'préconisait',
#   'une',
#   'période',
#   'de',
#   'treize',
#   'ans',
#   '.'],
#  ['Une',
#   'société',
#   'civile',
#   'fonctionnant',
#   'correctement',
#   "n'",
#   'est',
#   'pas',
#   'une',
#   'menace',
#   'mais',
#   'une',
#   'condition',
#   'sine',
#   'qua',
#   'non',
#   'à',
#   'un',
#   'gouvernement',
#   'correct',
#   '.'],
#  ['Ce',
#   'que',
#   "l'",
#   'auteur',
#   'essaie',
#   'de',
#   'dire',
#   "n'",
#   'est',
#   'pas',
#   'clair',
#   '.'],
#  ['Donc',
#   'je',
#   'me',
#   'demandais',
#   ',',
#   '"',
#   "Qu'",
#   'est',
#   '-ce',
#   'que',
#   'cette',
#   'chose',
#   'devant',
#   'moi',
#   ',',
#   'cette',
#   'espèce',
#   "d'",
#   'ordinateur',
#   '?',
#   '"'],
#  ['Je',
#   'ne',
#   'suis',
#   'pas',
#   'meilleur',
#   'que',
#   'ma',
#   'mère',
#   'pour',
#   'la',
#   'cuisine',
#   '.'],
#  ['Il',
#   'peut',
#   'nous',
#   'aider',
#   'à',
#   'neutraliser',
#   'le',
#   'mythe',
#   'selon',
#   'lequel',
#   'le',
#   'marché',
#   'intérieur',
#   'est',
#   'exclusivement',
#   'réservé',
#   'aux',
#   'entreprises',
#   'et',
#   'selon',
#   'lequel',
#   'les',
#   'consommateurs',
#   "n'",
#   'en',
#   'bénéficient',
#   'pas',
#   '.'],
#  ['Bien',
#   'entendu',
#   ',',
#   'mon',
#   'fils',
#   'apprend',
#   'à',
#   'partir',
#   'de',
#   'son',
#   'environnement',
#   'linguistique',
#   ',',
#   'mais',
#   "l'",
#   'environnement',
#   'apprend',
#   'de',
#   'lui',
#   '.'],
#  ['Cela', 'vous', 'dit', 'quelque', 'chose', '?'],
#  ['En',
#   'fin',
#   'de',
#   'compte',
#   ',',
#   "j'",
#   'ai',
#   'cru',
#   'comprendre',
#   'que',
#   'la',
#   'résolution',
#   'finale',
#   'a',
#   'été',
#   'atténuée',
#   ',',
#   'mais',
#   'je',
#   'pense',
#   'tout',
#   'de',
#   'même',
#   "qu'",
#   'il',
#   'est',
#   'inquiétant',
#   'que',
#   'ce',
#   'genre',
#   'de',
#   'choses',
#   'puisse',
#   'émaner',
#   'des',
#   'Nations',
#   'unies',
#   '.'],
#  ['Suivi',
#   'du',
#   'rapport',
#   'sur',
#   'la',
#   'concurrence',
#   'dans',
#   'le',
#   'secteur',
#   'des',
#   'professions',
#   'libérales',
#   '(',
#   'vote',
#   ')'],
#  ['En',
#   'niant',
#   'cette',
#   'réalité',
#   ',',
#   'nous',
#   'desservons',
#   'deux',
#   'fois',
#   'le',
#   'peuple',
#   'irakien',
#   'et',
#   'les',
#   'morts',
#   'continuent',
#   '.'],
#  ['Monsieur',
#   'le',
#   'Président',
#   ',',
#   'nous',
#   'tous',
#   'avons',
#   'pour',
#   'objectif',
#   'important',
#   'et',
#   'ambitieux',
#   'de',
#   'faire',
#   'de',
#   "l'",
#   'Europe',
#   "l'",
#   'espace',
#   'économique',
#   'le',
#   'plus',
#   'moderne',
#   'et',
#   'le',
#   'plus',
#   'attractif',
#   'du',
#   'monde',
#   'pour',
#   'les',
#   'entreprises',
#   'et',
#   'les',
#   'travailleurs',
#   '.'],
#  ['Nous',
#   'savons',
#   'parfaitement',
#   'que',
#   'les',
#   'conditions',
#   'politiques',
#   'mondiales',
#   'de',
#   'notre',
#   'neutralité',
#   'sont',
#   "aujourd'hui",
#   'différentes',
#   "d'",
#   'il',
#   'y',
#   'a',
#   'dix',
#   'ans',
#   '.'],
#  ['Différent',
#   'pays',
#   'et',
#   'instituts',
#   'de',
#   'recherche',
#   'dépensent',
#   'actuellement',
#   'des',
#   'sommes',
#   'considérables',
#   'en',
#   'recherche',
#   'sur',
#   'les',
#   'biocarburants',
#   'de',
#   'deuxième',
#   'et',
#   'troisième',
#   'génération',
#   '.'],
#  ['au',
#   'nom',
#   'du',
#   'groupe',
#   'PPE',
#   '.',
#   '-',
#   '(',
#   'DE',
#   ')',
#   'Monsieur',
#   'le',
#   'Président',
#   ',',
#   'Madame',
#   'la',
#   'présidente',
#   'en',
#   'exercice',
#   'du',
#   'Conseil',
#   ',',
#   'Monsieur',
#   'le',
#   'président',
#   'de',
#   'la',
#   'Commission',
#   ',',
#   'comme',
#   'cela',
#   'a',
#   'déjà',
#   'été',
#   'souligné',
#   ',',
#   'Schengen',
#   'est',
#   "l'",
#   'une',
#   'des',
#   'grandes',
#   'réalisations',
#   'de',
#   'notre',
#   'projet',
#   'européen',
#   'commun',
#   '.'],
#  ['Je',
#   'soutiens',
#   'intégralement',
#   'cette',
#   'résolution',
#   'du',
#   'Parlement',
#   'européen',
#   '.'],
#  ['Nous',
#   'ne',
#   'devrions',
#   'pas',
#   'cacher',
#   'nos',
#   'propres',
#   'problèmes',
#   'et',
#   'pointer',
#   'un',
#   'doigt',
#   'accusateur',
#   'seulement',
#   'sur',
#   'la',
#   'Turquie',
#   '.'],
#  ['Pour',
#   'cette',
#   'raison',
#   ',',
#   'nous',
#   'devons',
#   'rechercher',
#   'ensemble',
#   'des',
#   'moyens',
#   'de',
#   'réduire',
#   "l'",
#   'impact',
#   'négatif',
#   'que',
#   'peuvent',
#   'avoir',
#   'les',
#   'délocalisations',
#   '.'],
#  ['Ils',
#   'plaident',
#   "aujourd'hui",
#   'contre',
#   'elle',
#   '.',
#   'Au',
#   'nom',
#   'de',
#   'leur',
#   'droit',
#   'à',
#   'la',
#   'propriété',
#   '.'],
#  ['Un',
#   'sol',
#   'pur',
#   'est',
#   'un',
#   'problème',
#   'critique',
#   '-',
#   'la',
#   'nitrification',
#   ',',
#   'les',
#   'zones',
#   'mortes',
#   'dans',
#   'le',
#   'Golfe',
#   'du',
#   'Mexique',
#   '.'],
#  ['Lorsque',
#   'nous',
#   'avons',
#   'engagé',
#   'les',
#   'négociations',
#   'd’',
#   'adhésion',
#   'au',
#   'début',
#   'de',
#   'l’',
#   'année',
#   '2000',
#   'avec',
#   'six',
#   'autres',
#   'pays',
#   'candidats',
#   ',',
#   'il',
#   'nous',
#   'était',
#   'impossible',
#   'de',
#   'savoir',
#   'le',
#   'temps',
#   'que',
#   'prendraient',
#   'ces',
#   'négociations',
#   'pour',
#   'chacun',
#   'd’',
#   'entre',
#   'eux',
#   '.'],
#  ["J'", 'ai', 'encore', 'beaucoup', 'de', 'travail', 'à', 'finir', '.'],
#  ['Pour',
#   'terminer',
#   ',',
#   'le',
#   'groupe',
#   'PPE',
#   'approuve',
#   'les',
#   'orientations',
#   'du',
#   'Conseil',
#   'sur',
#   'la',
#   'sécurité',
#   'avec',
#   'le',
#   'nouveau',
#   'programme',
#   'de',
#   'Stockholm',
#   '.'],
#  ['Je',
#   'pense',
#   'aussi',
#   'qu’',
#   'il',
#   'est',
#   'essentiel',
#   'que',
#   'le',
#   'public',
#   'bénéficie',
#   'd’',
#   'un',
#   'intérêt',
#   'partisan',
#   'afin',
#   'de',
#   'pouvoir',
#   'être',
#   'repris',
#   'dans',
#   'ce',
#   'cadre',
#   'réglementaire',
#   '.'],
#  ['La',
#   'communauté',
#   'internationale',
#   "n'",
#   'a',
#   'toujours',
#   'pas',
#   'trouvé',
#   'de',
#   'moyen',
#   'pour',
#   'créer',
#   'la',
#   'pression',
#   'nécessaire',
#   'pour',
#   'arrêter',
#   'ce',
#   'génocide',
#   '.'],
#  ["J'",
#   'ai',
#   'suivi',
#   'la',
#   'présidence',
#   'suédoise',
#   'et',
#   'je',
#   'suis',
#   'resté',
#   'congelé',
#   'par',
#   'la',
#   'froideur',
#   'avec',
#   'laquelle',
#   'elle',
#   'a',
#   'presque',
#   'toujours',
#   'répondu',
#   '.',
#   'Moi',
#   ',',
#   'je',
#   'ne',
#   'pourrais',
#   'pas',
#   'le',
#   'faire',
#   '.'],
#  ['Les',
#   'pays',
#   'se',
#   'montrent',
#   'plus',
#   'durs',
#   'parce',
#   'que',
#   'les',
#   'flux',
#   'de',
#   'migration',
#   'peuvent',
#   'être',
#   'détournés',
#   'à',
#   'travers',
#   'les',
#   'juridictions',
#   '.'],
#  ['La',
#   'semaine',
#   'dernière',
#   ',',
#   'le',
#   'Conseil',
#   '"',
#   'Affaires',
#   'étrangères',
#   '"',
#   'a',
#   'discuté',
#   'de',
#   'la',
#   'situation',
#   'au',
#   'Proche',
#   '-',
#   'Orient',
#   'et',
#   'adopté',
#   'des',
#   'conclusions',
#   '.'],
#  ['par',
#   'écrit',
#   '.',
#   '-',
#   '(',
#   'EN',
#   ')',
#   'Les',
#   'simplifications',
#   'proposées',
#   'des',
#   'mesures',
#   'traitant',
#   'des',
#   'substances',
#   'pharmacologiquement',
#   'actives',
#   'dans',
#   'les',
#   'aliments',
#   "d'",
#   'origine',
#   'animale',
#   'doivent',
#   'être',
#   'saluées',
#   'et',
#   ',',
#   'par',
#   'conséquent',
#   ',',
#   'je',
#   'soutiens',
#   'le',
#   'rapport',
#   'de',
#   'Mme',
#   'Doyle',
#   '.'],
#  ['Maintenant',
#   ',',
#   'pour',
#   'commencer',
#   ',',
#   'je',
#   'dirais',
#   'que',
#   'nous',
#   'mangeons',
#   'beaucoup',
#   'trop',
#   'de',
#   'viande',
#   'dans',
#   'le',
#   'monde',
#   'occidental',
#   '.'],
#  ['Dans',
#   'notre',
#   'ère',
#   'empreinte',
#   'de',
#   'cynisme',
#   ',',
#   'beaucoup',
#   'pourraient',
#   'trouver',
#   'un',
#   'peu',
#   'désuète',
#   'une',
#   'telle',
#   'devise',
#   '(',
#   'ou',
#   ',',
#   'en',
#   'fait',
#   ',',
#   'du',
#   'pouvoir',
#   'de',
#   'toutes',
#   'les',
#   'devises',
#   'ou',
#   'de',
#   'tous',
#   'les',
#   'slogans',
#   ')',
#   '.'],
#  ['Les',
#   'uns',
#   'sont',
#   'dus',
#   'à',
#   'la',
#   'crise',
#   'proprement',
#   'dite',
#   ',',
#   'laquelle',
#   'a',
#   'commencé',
#   'au',
#   'printemps',
#   'de',
#   "l'",
#   'an',
#   'dernier',
#   '.'],
#  ['Elle',
#   'symbolise',
#   'donc',
#   'les',
#   'efforts',
#   'réalisés',
#   'pour',
#   'créer',
#   'une',
#   'relation',
#   'euro',
#   '-',
#   'atlantique',
#   'équilibrée',
#   'au',
#   'sein',
#   'de',
#   'laquelle',
#   "l'",
#   'Europe',
#   'maintient',
#   'son',
#   'indépendance',
#   ',',
#   'prend',
#   'des',
#   'initiatives',
#   'spécifiques',
#   'et',
#   'joue',
#   'ses',
#   'propres',
#   'cartes',
#   '.'],
#  ["L'",
#   'Espagne',
#   'a',
#   'promené',
#   'ses',
#   'adversaires',
#   '.',
#   'Les',
#   'Français',
#   'sont',
#   'apparus',
#   'léthargiques',
#   '.'],
#  ['Nous',
#   'avons',
#   'perdu',
#   '25',
#   '%',
#   'des',
#   'espèces',
#   'uniques',
#   'à',
#   'Hawaï',
#   'ces',
#   '20',
#   'dernières',
#   'années',
#   ',',
#   'la',
#   'Californie',
#   'devrait',
#   'perdre',
#   '25',
#   '%',
#   'de',
#   'ses',
#   'espèces',
#   'les',
#   '40',
#   'prochaines',
#   'années',
#   '.'],
#  ['Et',
#   'pourtant',
#   ',',
#   'elle',
#   'est',
#   'faite',
#   'd´éléments',
#   'invisibles',
#   ',',
#   'ou',
#   'quasiment',
#   'invisibles',
#   ',',
#   'à',
#   'l´œil',
#   'nu',
#   ',',
#   'des',
#   'bactéries',
#   'et',
#   'des',
#   'grains',
#   'de',
#   'sable',
#   '.'],
#  ['Ce',
#   'n’',
#   'est',
#   'pas',
#   'nécessairement',
#   'bien',
#   'pour',
#   'la',
#   'société',
#   ',',
#   'mais',
#   'c’',
#   'est',
#   'ce',
#   'que',
#   'les',
#   'individus',
#   'et',
#   'la',
#   'famille',
#   'choisissent',
#   '.'],
#  ['Or',
#   ',',
#   'les',
#   'chiffres',
#   'du',
#   'chômage',
#   'sont',
#   'très',
#   'différents',
#   'dans',
#   'ces',
#   'deux',
#   'pays',
#   ':',
#   '9',
#   ',',
#   '5',
#   '%',
#   'en',
#   'Belgique',
#   'et',
#   'de',
#   "l'",
#   'ordre',
#   'de',
#   '6',
#   '%',
#   'aux',
#   'Pays',
#   '-',
#   'Bas',
#   '.'],
#  ['Malheureusement',
#   ',',
#   'elle',
#   'ne',
#   'pouvait',
#   'être',
#   'parmi',
#   'nous',
#   "aujourd'hui",
#   '.'],
#  ['Et',
#   'le',
#   'Brésil',
#   'a',
#   'déjà',
#   'déclaré',
#   'qu’',
#   'il',
#   'n’',
#   'avait',
#   'pas',
#   'de',
#   'problèmes',
#   'avec',
#   'la',
#   'Chine',
#   ',',
#   'laquelle',
#   'est',
#   'récemment',
#   'devenue',
#   'son',
#   'plus',
#   'gros',
#   'marché',
#   'd’',
#   'exportation',
#   '.'],
#  ['John', 'a', 'rencontré', 'Marie', 'en', 'allant', 'à', "l'", 'école', '.'],
#  ['Assurément',
#   ',',
#   'la',
#   'directive',
#   'trop',
#   'détaillée',
#   'va',
#   'à',
#   'l’',
#   'encontre',
#   'des',
#   'principes',
#   'de',
#   'subsidiarité',
#   'et',
#   'de',
#   'proportionnalité',
#   '.'],
#  ...]
